# %%
import numpy as np

# %%
import sys
import os

sys.path.insert(0, os.path.abspath("../.."))
sys.path.append(os.path.abspath("../../backend"))
sys.path.append(os.path.abspath(""))

from rdflib.plugins.stores.sparqlstore import SPARQLStore

from backend.ontology import OntologyManager, OntologyConfig, Graph
from backend.explorative.explorative_support import GuidanceManager
from backend.explorative.llm_query import (
    EnrichedEntitiesRelations,
    LLMQuery,
    QueryProgress,
)
from tqdm import tqdm
import pandas as pd

# %%
from seqeval import metrics
from sklearn.metrics import f1_score
import networkx as nx

# %%
store = SPARQLStore(
    "http://localhost:7012/",
    method="POST_FORM",
    params={"infer": False, "sameAs": False},
)
graph = Graph(store=store)

config = OntologyConfig()

ontology_manager = OntologyManager(config, graph)
topic_man = GuidanceManager(ontology_manager,
                            llm_model_id="unsloth/Mistral-Small-3.1-24B-Instruct-2503-GGUF",
                            llm_quant_model="*Q6_K.gguf")

query_man = LLMQuery(topic_man)

# %%
generated_queries = pd.read_csv("llama_examples.csv", index_col=0)
generated_queries["erl"] = generated_queries["erl"].apply(
    lambda x: EnrichedEntitiesRelations.model_validate_json(x)
)
generated_queries
# Out:
#                                                     erl  \
# 0     relations=[EnrichedRelation(entity='Organisati...
# 1     relations=[EnrichedRelation(entity='Organisati...
# 2     relations=[EnrichedRelation(entity='written wo...
# 3     relations=[EnrichedRelation(entity='written wo...
# 4     relations=[EnrichedRelation(entity='work', rel...
# ...                                                 ...
# 1795  relations=[EnrichedRelation(entity='ethnic gro...
# 1796  relations=[EnrichedRelation(entity='Organisati...
# 1797  relations=[EnrichedRelation(entity='Organisati...
# 1798  relations=[EnrichedRelation(entity='person', r...
# 1799  relations=[EnrichedRelation(entity='person', r...
#
#                                                response  generator  n_nodes  \
# 0     A member of an organization died in a stream a...      llama        3
# 1     a Organisation member has a death place with s...  templated        3
# 2     A multi-volume publication has volumes of a wr...      llama        3
# 3     a written work has a starring with actor, and ...  templated        3
# 4     A work features an actor and is directed by a ...      llama        3
# ...                                                 ...        ...      ...
# 1795  a ethnic group has a population place with pop...  templated       10
# 1796  An Organisation member has nationality of a co...      llama       10
# 1797  a Organisation member has a nationality with c...  templated       10
# 1798  - A person is born in a populated place.\n- A ...      llama       10
# 1799  a person has a birth place with populated plac...  templated       10
#
#       seed
# 0        0
# 1        0
# 2        1
# 3        1
# 4        2
# ...    ...
# 1795   297
# 1796   298
# 1797   298
# 1798   299
# 1799   299
#
# [1800 rows x 5 columns]

# %%
generated_query = generated_queries.iloc[1]
target_erl: EnrichedEntitiesRelations = generated_query["erl"]
query = generated_query["response"]
progress = QueryProgress(id="0", max_steps=1, start_time="0")
query_man.run_query(query=query, progress=progress)
# Out:
# Loading LLM model unsloth/Mistral-Small-3.1-24B-Instruct-2503-GGUF None
# (…)al-Small-3.1-24B-Instruct-2503-Q6_K.gguf:   0%|          | 0.00/19.3G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       3 query = generated_query["response"]
#       4 progress = QueryProgress(id="0", max_steps=1, start_time="0")
# ----> 5 query_man.run_query(query=query, progress=progress)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/explorative/llm_query.py:172, in LLMQuery.run_query(self, progress, query)
#     169 progress.message = "Querying entities and relations"
#     170 self.cache[progress.id] = progress
# --> 172 erl = self.query_erl(query)
#     173 progress.progress = 2
#     174 progress.message = "Fetching possible candidates"
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/explorative/llm_query.py:234, in LLMQuery.query_erl(self, query)
#     227     messages.extend(
#     228         [
#     229             {"role": "user", "content": ERL_PROMPT_EXAMPLE[0]},
#     230             {"role": "assistant", "content": ERL_PROMPT_EXAMPLE[1]},
#     231         ]
#     232     )
#     233 messages.append({"role": "user", "content": query})
# --> 234 response = self.model.create_chat_completion(
#     235     grammar=self.grammar_erl,
#     236     messages=messages,
#     237     max_tokens=self.max_tokens,
#     238     temperature=self.temperature,
#     239 )
#     240 response_msg = response["choices"][0]["message"]["content"]
#     241 return EntitiesRelations.model_validate_json(response_msg)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/explorative/llm_query.py:220, in LLMQuery.model(self)
#     218 @property
#     219 def model(self) -> Llama:
# --> 220     return self.guidance_man.llama_model
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/explorative/explorative_support.py:85, in GuidanceManager.llama_model(self)
#      83     self.__lama_model = self.langchain_model
#      84 elif self.llm_model_id is not None:
# ---> 85     self.__lama_model = Llama.from_pretrained(
#      86         repo_id=self.llm_model_id,
#      87         filename=self.llm_quant_model,
#      88         n_batch=2048,
#      89         n_ubatch=512,
#      90         n_ctx=self.ctx_size,
#      91         n_gpu_layers=-1,
#      92         n_threads=6,
#      93         embedding=False,
#      94     )
#      95 return self.__lama_model
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:2301, in Llama.from_pretrained(cls, repo_id, filename, additional_files, local_dir, local_dir_use_symlinks, cache_dir, **kwargs)
#    2298 filename = Path(matching_file).name
#    2300 # download the file
# -> 2301 hf_hub_download(
#    2302     repo_id=repo_id,
#    2303     filename=filename,
#    2304     subfolder=subfolder,
#    2305     local_dir=local_dir,
#    2306     local_dir_use_symlinks=local_dir_use_symlinks,
#    2307     cache_dir=cache_dir,
#    2308 )
#    2310 if additional_files:
#    2311     for additonal_file_name in additional_files:
#    2312         # find the additional shard file:
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     842     return _hf_hub_download_to_local_dir(
#     843         # Destination
#     844         local_dir=local_dir,
#    (...)
#     859         local_files_only=local_files_only,
#     860     )
#     861 else:
# --> 862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#     865         # File info
#     866         repo_id=repo_id,
#     867         filename=filename,
#     868         repo_type=repo_type,
#     869         revision=revision,
#     870         # HTTP info
#     871         endpoint=endpoint,
#     872         etag_timeout=etag_timeout,
#     873         headers=hf_headers,
#     874         proxies=proxies,
#     875         token=token,
#     876         # Additional options
#     877         local_files_only=local_files_only,
#     878         force_download=force_download,
#     879     )
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1011, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1009 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1010 with WeakFileLock(lock_path):
# -> 1011     _download_to_tmp_and_move(
#    1012         incomplete_path=Path(blob_path + ".incomplete"),
#    1013         destination_path=Path(blob_path),
#    1014         url_to_download=url_to_download,
#    1015         proxies=proxies,
#    1016         headers=headers,
#    1017         expected_size=expected_size,
#    1018         filename=filename,
#    1019         force_download=force_download,
#    1020     )
#    1021     if not os.path.exists(pointer_path):
#    1022         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1547, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1544         _check_disk_space(expected_size, incomplete_path.parent)
#    1545         _check_disk_space(expected_size, destination_path.parent)
# -> 1547     http_get(
#    1548         url_to_download,
#    1549         f,
#    1550         proxies=proxies,
#    1551         resume_size=resume_size,
#    1552         headers=headers,
#    1553         expected_size=expected_size,
#    1554     )
#    1556 logger.info(f"Download complete. Moving file to {destination_path}")
#    1557 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:454, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     452 new_resume_size = resume_size
#     453 try:
# --> 454     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     455         if chunk:  # filter out keep-alive new chunks
#     456             progress.update(len(chunk))
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/urllib3/response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066         data = self.read(amt=amt, decode_content=decode_content)
#    1068         if data:
#    1069             yield data
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/.venv/lib/python3.12/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
(
    [[ent.type for ent in target_erl.entities]],
    [[ent.type for ent in progress.enriched_relations.entities]],
)
# Out:
# ([['written work', 'actor', 'multi volume publication']],
#  [['work', 'actor', 'multi volume publication']])

# %%
def graph_from_erl(erl: EnrichedEntitiesRelations):
    G = nx.DiGraph()
    for node in erl.entities:
        G.add_node(node.identifier, label=node.type)
    for link in erl.relations:
        G.add_edge(
            link.entity,
            link.target,
            weight=link.link.instance_count,
            label=link.relation,
        )
    return G

# %%
def f1k(y_true, y_pred, k: int = None):
    rel_set = set(y_true)
    # print(rel_set)
    doc_set = set(y_pred[:k])
    tp = len(doc_set.intersection(rel_set))  # docs that are in both -relevant docs
    fp = len(
        doc_set.difference(rel_set)
    )  # docs that are not in relevant set - irrelevant docs (false positiv)
    fn = len(
        rel_set.difference(doc_set)
    )  # relevant docs that are not present in doc set - missing docs
    if tp == 0:
        return 0
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    return 2 * precision * recall / (precision + recall)

# %%
f1_score_ents = f1k(
    [ent.type for ent in target_erl.entities],
    [ent.type for ent in progress.enriched_relations.entities],
)
f1_score_ents
# Out:
# 0.6666666666666666

# %%
target_graph = graph_from_erl(target_erl)
retrieved_grap = graph_from_erl(progress.enriched_relations)


def edge_match(a, b):
    return a["label"] == b["label"] if "label" in a and "label" in b else False


def node_match(a, b):
    return a["label"] == b["label"] if "label" in a and "label" in b else False


1 - nx.graph_edit_distance(
    target_graph, retrieved_grap, edge_match=edge_match, node_match=node_match
) / (
    len(target_graph.edges)
    + len(retrieved_grap.edges)
    + len(target_graph.nodes)
    + len(retrieved_grap.nodes)
)
# Out:
# 0.7

# %%
def run_eval(query: pd.Series, llm_query: LLMQuery):
    target_erl: EnrichedEntitiesRelations = query["erl"]
    query = query["response"]
    progress = QueryProgress(id="0", max_steps=1, start_time="0")
    llm_query.run_query(query=query, progress=progress)
    f1_score_ents = f1k(
        [ent.type for ent in target_erl.entities],
        [ent.type for ent in progress.enriched_relations.entities],
    )
    target_graph = graph_from_erl(target_erl)
    retrieved_grap = graph_from_erl(progress.enriched_relations)
    edit_distance = 1 - nx.graph_edit_distance(
        target_graph, retrieved_grap, edge_match=edge_match, node_match=node_match
    ) / (
        len(target_graph.edges)
        + len(retrieved_grap.edges)
        + len(target_graph.nodes)
        + len(retrieved_grap.nodes)
    )
    return f1_score_ents, edit_distance


def run_evals(queries: pd.DataFrame, llm_query: LLMQuery):
    results = queries.copy()
    for i, query in tqdm(queries.iterrows(), total=len(queries)):
        f1_score_ents, edit_distance = run_eval(query, llm_query)
        results.loc[i, "f1_score"] = f1_score_ents
        results.loc[i, "edit_distance"] = edit_distance
    return results


for zero_shot in [True, False]:
    print(f"oneshot={zero_shot}")
    query_man = LLMQuery(topic_man, zero_shot=zero_shot)
    results = run_evals(generated_queries, llm_query=query_man)
    results.to_csv(
        f"restuls/eval_results_{'oneshot' if zero_shot else 'zeroshot'}_{topic_man.llm_model_id.replace('/', '-')}.csv"
    )
# Out:
# oneshot=True
#   0%|          | 0/897 [00:00<?, ?it/s]
# Llama.generate: 6 prefix-match hit, remaining 120 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /   120 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   264 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    8165.69 ms /   384 tokens
# Llama.generate: 6 prefix-match hit, remaining 98 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    98 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   325 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    9485.19 ms /   423 tokens
#   0%|          | 1/897 [00:20<5:00:07, 20.10s/it]Llama.generate: 6 prefix-match hit, remaining 92 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    92 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   334 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =   10092.91 ms /   426 tokens
# Llama.generate: 6 prefix-match hit, remaining 70 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    70 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   186 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    5395.70 ms /   256 tokens
#   0%|          | 2/897 [00:37<4:39:40, 18.75s/it]Llama.generate: 6 prefix-match hit, remaining 89 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    89 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   382 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =   11355.57 ms /   471 tokens
# Llama.generate: 6 prefix-match hit, remaining 67 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    67 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   286 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    8433.32 ms /   353 tokens
#   0%|          | 3/897 [01:00<5:08:17, 20.69s/it]Llama.generate: 6 prefix-match hit, remaining 87 prompt tokens to eval
#   0%|          | 3/897 [01:05<5:25:35, 21.85s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 35
#      33 print(f"oneshot={zero_shot}")
#      34 query_man = LLMQuery(topic_man, zero_shot=zero_shot)
# ---> 35 results = run_evals(generated_queries, llm_query=query_man)
#      36 results.to_csv(
#      37     f"restuls/eval_results_{'oneshot' if zero_shot else 'zeroshot'}_{topic_man.llm_model_id.replace('/', '-')}.csv"
#      38 )
#
# Cell In[11], line 26, in run_evals(queries, llm_query)
#      24 results = queries.copy()
#      25 for i, query in tqdm(queries.iterrows(), total=len(queries)):
# ---> 26     f1_score_ents, edit_distance = run_eval(query, llm_query)
#      27     results.loc[i, "f1_score"] = f1_score_ents
#      28     results.loc[i, "edit_distance"] = edit_distance
#
# Cell In[11], line 5, in run_eval(query, llm_query)
#       3 query = query["response"]
#       4 progress = QueryProgress(id="0", max_steps=1, start_time="0")
# ----> 5 llm_query.run_query(query=query, progress=progress)
#       6 f1_score_ents = f1k(
#       7     [ent.type for ent in target_erl.entities],
#       8     [ent.type for ent in progress.enriched_relations.entities],
#       9 )
#      10 target_graph = graph_from_erl(target_erl)
#
# File ~/cgv/hereditary/onset/backend/llm_query.py:218, in LLMQuery.run_query(self, progress, query)
#     215 progress.message = "Querying entities and relations"
#     216 self.cache[progress.id] = progress
# --> 218 erl = self.query_erl(query)
#     219 progress.progress = 2
#     220 progress.message = "Fetching possible candidates"
#
# File ~/cgv/hereditary/onset/backend/llm_query.py:280, in LLMQuery.query_erl(self, query)
#     273     messages.extend(
#     274         [
#     275             {"role": "user", "content": ERL_PROMPT_EXAMPLE[0]},
#     276             {"role": "assistant", "content": ERL_PROMPT_EXAMPLE[1]},
#     277         ]
#     278     )
#     279 messages.append({"role": "user", "content": query})
# --> 280 response = self.model.create_chat_completion(
#     281     grammar=self.grammar_erl,
#     282     messages=messages,
#     283     max_tokens=-1,
#     284     temperature=self.temperature,
#     285 )
#     286 response_msg = response["choices"][0]["message"]["content"]
#     287 return EntitiesRelations.model_validate_json(response_msg)
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:1998, in Llama.create_chat_completion(self, messages, functions, function_call, tools, tool_choice, temperature, top_p, top_k, min_p, typical_p, stream, stop, seed, response_format, max_tokens, presence_penalty, frequency_penalty, repeat_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, logits_processor, grammar, logit_bias, logprobs, top_logprobs)
#    1960 """Generate a chat completion from a list of messages.
#    1961
#    1962 Args:
#    (...)
#    1991     Generated chat completion or a stream of chat completion chunks.
#    1992 """
#    1993 handler = (
#    1994     self.chat_handler
#    1995     or self._chat_handlers.get(self.chat_format)
#    1996     or llama_chat_format.get_chat_completion_handler(self.chat_format)
#    1997 )
# -> 1998 return handler(
#    1999     llama=self,
#    2000     messages=messages,
#    2001     functions=functions,
#    2002     function_call=function_call,
#    2003     tools=tools,
#    2004     tool_choice=tool_choice,
#    2005     temperature=temperature,
#    2006     top_p=top_p,
#    2007     top_k=top_k,
#    2008     min_p=min_p,
#    2009     typical_p=typical_p,
#    2010     logprobs=logprobs,
#    2011     top_logprobs=top_logprobs,
#    2012     stream=stream,
#    2013     stop=stop,
#    2014     seed=seed,
#    2015     response_format=response_format,
#    2016     max_tokens=max_tokens,
#    2017     presence_penalty=presence_penalty,
#    2018     frequency_penalty=frequency_penalty,
#    2019     repeat_penalty=repeat_penalty,
#    2020     tfs_z=tfs_z,
#    2021     mirostat_mode=mirostat_mode,
#    2022     mirostat_tau=mirostat_tau,
#    2023     mirostat_eta=mirostat_eta,
#    2024     model=model,
#    2025     logits_processor=logits_processor,
#    2026     grammar=grammar,
#    2027     logit_bias=logit_bias,
#    2028 )
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama_chat_format.py:662, in chat_formatter_to_chat_completion_handler.<locals>.chat_completion_handler(llama, messages, functions, function_call, tools, tool_choice, temperature, top_p, top_k, min_p, typical_p, stream, stop, seed, response_format, max_tokens, presence_penalty, frequency_penalty, repeat_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, logits_processor, grammar, logit_bias, logprobs, top_logprobs, **kwargs)
#     657             print(str(e), file=sys.stderr)
#     658         grammar = llama_grammar.LlamaGrammar.from_string(
#     659             llama_grammar.JSON_GBNF, verbose=llama.verbose
#     660         )
# --> 662 completion_or_chunks = llama.create_completion(
#     663     prompt=prompt,
#     664     temperature=temperature,
#     665     top_p=top_p,
#     666     top_k=top_k,
#     667     min_p=min_p,
#     668     typical_p=typical_p,
#     669     logprobs=top_logprobs if logprobs else None,
#     670     stream=stream,
#     671     stop=stop,
#     672     seed=seed,
#     673     max_tokens=max_tokens,
#     674     presence_penalty=presence_penalty,
#     675     frequency_penalty=frequency_penalty,
#     676     repeat_penalty=repeat_penalty,
#     677     tfs_z=tfs_z,
#     678     mirostat_mode=mirostat_mode,
#     679     mirostat_tau=mirostat_tau,
#     680     mirostat_eta=mirostat_eta,
#     681     model=model,
#     682     logits_processor=logits_processor,
#     683     stopping_criteria=stopping_criteria,
#     684     grammar=grammar,
#     685     logit_bias=logit_bias,
#     686 )
#     687 if tool is not None:
#     688     tool_name = tool["function"]["name"]
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:1832, in Llama.create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1830     chunks: Iterator[CreateCompletionStreamResponse] = completion_or_chunks
#    1831     return chunks
# -> 1832 completion: Completion = next(completion_or_chunks)  # type: ignore
#    1833 return completion
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:1317, in Llama._create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1315 finish_reason = "length"
#    1316 multibyte_fix = 0
# -> 1317 for token in self.generate(
#    1318     prompt_tokens,
#    1319     top_k=top_k,
#    1320     top_p=top_p,
#    1321     min_p=min_p,
#    1322     typical_p=typical_p,
#    1323     temp=temperature,
#    1324     tfs_z=tfs_z,
#    1325     mirostat_mode=mirostat_mode,
#    1326     mirostat_tau=mirostat_tau,
#    1327     mirostat_eta=mirostat_eta,
#    1328     frequency_penalty=frequency_penalty,
#    1329     presence_penalty=presence_penalty,
#    1330     repeat_penalty=repeat_penalty,
#    1331     stopping_criteria=stopping_criteria,
#    1332     logits_processor=logits_processor,
#    1333     grammar=grammar,
#    1334 ):
#    1335     if llama_cpp.llama_token_is_eog(self._model.model, token):
#    1336         text = self.detokenize(completion_tokens, prev_tokens=prompt_tokens)
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:911, in Llama.generate(self, tokens, top_k, top_p, min_p, typical_p, temp, repeat_penalty, reset, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, penalize_nl, logits_processor, stopping_criteria, grammar)
#     909 self.eval(tokens)
#     910 while sample_idx < self.n_tokens:
# --> 911     token = self.sample(
#     912         top_k=top_k,
#     913         top_p=top_p,
#     914         min_p=min_p,
#     915         typical_p=typical_p,
#     916         temp=temp,
#     917         repeat_penalty=repeat_penalty,
#     918         frequency_penalty=frequency_penalty,
#     919         presence_penalty=presence_penalty,
#     920         tfs_z=tfs_z,
#     921         mirostat_mode=mirostat_mode,
#     922         mirostat_tau=mirostat_tau,
#     923         mirostat_eta=mirostat_eta,
#     924         logits_processor=logits_processor,
#     925         grammar=grammar,
#     926         penalize_nl=penalize_nl,
#     927         idx=sample_idx,
#     928     )
#     930     sample_idx += 1
#     931     if stopping_criteria is not None and stopping_criteria(
#     932         self._input_ids[: sample_idx], self._scores[sample_idx - self.n_tokens, :]
#     933     ):
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:812, in Llama.sample(self, top_k, top_p, min_p, typical_p, temp, repeat_penalty, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_eta, mirostat_tau, penalize_nl, logits_processor, grammar, idx)
#     809 ridx = idx - self.n_tokens if idx is not None else -1
#     811 assert self.ctx is not None
# --> 812 token = self._sampler.sample(self._ctx, ridx)
#     813 if tmp_sampler:
#     814     self._sampler = None
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/_internals.py:850, in LlamaSampler.sample(self, ctx, idx)
#     848 def sample(self, ctx: LlamaContext, idx: int) -> int:
#     849     assert self.sampler is not None
# --> 850     return llama_cpp.llama_sampler_sample(self.sampler, ctx.ctx, idx)
#
# KeyboardInterrupt:
