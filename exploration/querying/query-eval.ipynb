# %%
import numpy as np

# %%
import sys
import os

sys.path.insert(0, os.path.abspath("../.."))
sys.path.append(os.path.abspath("../../backend"))
sys.path.append(os.path.abspath(""))

from rdflib.plugins.stores.sparqlstore import SPARQLStore

from backend.ontology import OntologyManager, OntologyConfig, Graph
from backend.explorative.explorative_support import GuidanceManager
from backend.explorative.llm_query import (
    EnrichedEntitiesRelations,
    LLMQuery,
    QueryProgress,
)
from tqdm import tqdm
import pandas as pd

# %%
from seqeval import metrics
from sklearn.metrics import f1_score
import networkx as nx

# %%
store = SPARQLStore(
    "http://localhost:7012/",
    method="POST_FORM",
    params={"infer": False, "sameAs": False},
)
graph = Graph(store=store)

config = OntologyConfig()

ontology_manager = OntologyManager(config, graph)
topic_man = GuidanceManager(ontology_manager,
                            llm_model_id="unsloth/Mistral-Small-3.1-24B-Instruct-2503-GGUF",
                            llm_quant_model="*Q6_K.gguf")

query_man = LLMQuery(topic_man)

# %%
generated_queries = pd.read_csv("llama_examples.csv", index_col=0)
generated_queries["erl"] = generated_queries["erl"].apply(
    lambda x: EnrichedEntitiesRelations.model_validate_json(x)
)
generated_queries
# Out:
#                                                     erl  \
# 0     relations=[EnrichedRelation(entity='Organisati...
# 1     relations=[EnrichedRelation(entity='Organisati...
# 2     relations=[EnrichedRelation(entity='written wo...
# 3     relations=[EnrichedRelation(entity='written wo...
# 4     relations=[EnrichedRelation(entity='work', rel...
# ...                                                 ...
# 1795  relations=[EnrichedRelation(entity='ethnic gro...
# 1796  relations=[EnrichedRelation(entity='Organisati...
# 1797  relations=[EnrichedRelation(entity='Organisati...
# 1798  relations=[EnrichedRelation(entity='person', r...
# 1799  relations=[EnrichedRelation(entity='person', r...
#
#                                                response  generator  n_nodes  \
# 0     A member of an organization died in a stream a...      llama        3
# 1     a Organisation member has a death place with s...  templated        3
# 2     A multi-volume publication has volumes of a wr...      llama        3
# 3     a written work has a starring with actor, and ...  templated        3
# 4     A work features an actor and is directed by a ...      llama        3
# ...                                                 ...        ...      ...
# 1795  a ethnic group has a population place with pop...  templated       10
# 1796  An Organisation member has nationality of a co...      llama       10
# 1797  a Organisation member has a nationality with c...  templated       10
# 1798  - A person is born in a populated place.\n- A ...      llama       10
# 1799  a person has a birth place with populated plac...  templated       10
#
#       seed
# 0        0
# 1        0
# 2        1
# 3        1
# 4        2
# ...    ...
# 1795   297
# 1796   298
# 1797   298
# 1798   299
# 1799   299
#
# [1800 rows x 5 columns]

# %%
generated_query = generated_queries.iloc[1]
target_erl: EnrichedEntitiesRelations = generated_query["erl"]
query = generated_query["response"]
progress = QueryProgress(id="0", max_steps=1, start_time="0")
query_man.run_query(query=query, progress=progress)
# Out:
# Loading LLM model unsloth/Mistral-Small-3.1-24B-Instruct-2503-GGUF None
# (…)al-Small-3.1-24B-Instruct-2503-Q6_K.gguf:   0%|          | 0.00/19.3G [00:00<?, ?B/s]
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    yes
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: NVIDIA GeForce RTX 4090, compute capability 8.9, VMM: yes
# llama_load_model_from_file: using device CUDA0 (NVIDIA GeForce RTX 4090) - 23528 MiB free
# llama_model_loader: loaded meta data with 39 key-value pairs and 363 tensors from /home/bkantz/.cache/huggingface/hub/models--unsloth--Mistral-Small-3.1-24B-Instruct-2503-GGUF/snapshots/1e4102073ec4b0d9f0eb305f04418f186e76a9b5/./Mistral-Small-3.1-24B-Instruct-2503-Q6_K.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Mistral-Small-3.1-24B-Instruct-2503
# llama_model_loader: - kv   3:                            general.version str              = 2503
# llama_model_loader: - kv   4:                           general.finetune str              = Instruct
# llama_model_loader: - kv   5:                           general.basename str              = Mistral-Small-3.1-24B-Instruct-2503
# llama_model_loader: - kv   6:                       general.quantized_by str              = Unsloth
# llama_model_loader: - kv   7:                         general.size_label str              = 24B
# llama_model_loader: - kv   8:                           general.repo_url str              = https://huggingface.co/unsloth
# llama_model_loader: - kv   9:                          llama.block_count u32              = 40
# llama_model_loader: - kv  10:                       llama.context_length u32              = 131072
# llama_model_loader: - kv  11:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv  12:                  llama.feed_forward_length u32              = 32768
# llama_model_loader: - kv  13:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv  14:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv  15:                       llama.rope.freq_base f32              = 1000000000.000000
# llama_model_loader: - kv  16:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  17:                 llama.attention.key_length u32              = 128
# llama_model_loader: - kv  18:               llama.attention.value_length u32              = 128
# llama_model_loader: - kv  19:                           llama.vocab_size u32              = 131072
# llama_model_loader: - kv  20:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv  21:                       tokenizer.ggml.model str              = gpt2
# llama_model_loader: - kv  22:                         tokenizer.ggml.pre str              = tekken
# llama_model_loader: - kv  23:                      tokenizer.ggml.tokens arr[str,131072]  = ["<unk>", "<s>", "</s>", "[INST]", "[...
# llama_model_loader: - kv  24:                  tokenizer.ggml.token_type arr[i32,131072]  = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# Exception ignored on calling ctypes callback function: <function llama_log_callback at 0x7f6c10338d60>
# Traceback (most recent call last):
#   File "/home/bkantz/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/_logger.py", line 39, in llama_log_callback
#     print(text.decode("utf-8"), end="", flush=True, file=sys.stderr)
#           ^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc4 in position 128: invalid continuation byte
# llama_model_loader: - kv  26:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  27:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  28:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  29:            tokenizer.ggml.padding_token_id u32              = 11
# llama_model_loader: - kv  30:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  31:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  32:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  33:               general.quantization_version u32              = 2
# llama_model_loader: - kv  34:                          general.file_type u32              = 18
# llama_model_loader: - kv  35:                      quantize.imatrix.file str              = Mistral-Small-3.1-24B-Instruct-2503-G...
# llama_model_loader: - kv  36:                   quantize.imatrix.dataset str              = unsloth_calibration_Mistral-Small-3.1...
# llama_model_loader: - kv  37:             quantize.imatrix.entries_count i32              = 280
# llama_model_loader: - kv  38:              quantize.imatrix.chunks_count i32              = 55
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q6_K:  282 tensors
# llm_load_vocab: control token:    216 '<SPECIAL_216>' is not marked as EOG
# llm_load_vocab: control token:    408 '<SPECIAL_408>' is not marked as EOG
# llm_load_vocab: control token:    845 '<SPECIAL_845>' is not marked as EOG
# llm_load_vocab: control token:    555 '<SPECIAL_555>' is not marked as EOG
# llm_load_vocab: control token:    257 '<SPECIAL_257>' is not marked as EOG
# llm_load_vocab: control token:    474 '<SPECIAL_474>' is not marked as EOG
# llm_load_vocab: control token:    241 '<SPECIAL_241>' is not marked as EOG
# llm_load_vocab: control token:    646 '<SPECIAL_646>' is not marked as EOG
# llm_load_vocab: control token:    601 '<SPECIAL_601>' is not marked as EOG
# llm_load_vocab: control token:    905 '<SPECIAL_905>' is not marked as EOG
# llm_load_vocab: control token:    168 '<SPECIAL_168>' is not marked as EOG
# llm_load_vocab: control token:     37 '<SPECIAL_37>' is not marked as EOG
# llm_load_vocab: control token:    125 '<SPECIAL_125>' is not marked as EOG
# llm_load_vocab: control token:     95 '<SPECIAL_95>' is not marked as EOG
# llm_load_vocab: control token:    304 '<SPECIAL_304>' is not marked as EOG
# llm_load_vocab: control token:    706 '<SPECIAL_706>' is not marked as EOG
# llm_load_vocab: control token:    423 '<SPECIAL_423>' is not marked as EOG
# llm_load_vocab: control token:      6 '[/AVAILABLE_TOOLS]' is not marked as EOG
# llm_load_vocab: control token:    592 '<SPECIAL_592>' is not marked as EOG
# llm_load_vocab: control token:    409 '<SPECIAL_409>' is not marked as EOG
# llm_load_vocab: control token:    231 '<SPECIAL_231>' is not marked as EOG
# llm_load_vocab: control token:    607 '<SPECIAL_607>' is not marked as EOG
# llm_load_vocab: control token:      7 '[TOOL_RESULTS]' is not marked as EOG
# llm_load_vocab: control token:    138 '<SPECIAL_138>' is not marked as EOG
# llm_load_vocab: control token:    455 '<SPECIAL_455>' is not marked as EOG
# llm_load_vocab: control token:    801 '<SPECIAL_801>' is not marked as EOG
# llm_load_vocab: control token:    288 '<SPECIAL_288>' is not marked as EOG
# llm_load_vocab: control token:    619 '<SPECIAL_619>' is not marked as EOG
# llm_load_vocab: control token:    133 '<SPECIAL_133>' is not marked as EOG
# llm_load_vocab: control token:    827 '<SPECIAL_827>' is not marked as EOG
# llm_load_vocab: control token:    771 '<SPECIAL_771>' is not marked as EOG
# llm_load_vocab: control token:    723 '<SPECIAL_723>' is not marked as EOG
# llm_load_vocab: control token:    494 '<SPECIAL_494>' is not marked as EOG
# llm_load_vocab: control token:    444 '<SPECIAL_444>' is not marked as EOG
# llm_load_vocab: control token:    422 '<SPECIAL_422>' is not marked as EOG
# llm_load_vocab: control token:    441 '<SPECIAL_441>' is not marked as EOG
# llm_load_vocab: control token:    372 '<SPECIAL_372>' is not marked as EOG
# llm_load_vocab: control token:    874 '<SPECIAL_874>' is not marked as EOG
# llm_load_vocab: control token:    137 '<SPECIAL_137>' is not marked as EOG
# llm_load_vocab: control token:    250 '<SPECIAL_250>' is not marked as EOG
# llm_load_vocab: control token:    840 '<SPECIAL_840>' is not marked as EOG
# llm_load_vocab: control token:    846 '<SPECIAL_846>' is not marked as EOG
# llm_load_vocab: control token:    465 '<SPECIAL_465>' is not marked as EOG
# llm_load_vocab: control token:    425 '<SPECIAL_425>' is not marked as EOG
# llm_load_vocab: control token:    984 '<SPECIAL_984>' is not marked as EOG
# llm_load_vocab: control token:    328 '<SPECIAL_328>' is not marked as EOG
# llm_load_vocab: control token:    186 '<SPECIAL_186>' is not marked as EOG
# llm_load_vocab: control token:    973 '<SPECIAL_973>' is not marked as EOG
# llm_load_vocab: control token:    394 '<SPECIAL_394>' is not marked as EOG
# llm_load_vocab: control token:    522 '<SPECIAL_522>' is not marked as EOG
# llm_load_vocab: control token:    385 '<SPECIAL_385>' is not marked as EOG
# llm_load_vocab: control token:    496 '<SPECIAL_496>' is not marked as EOG
# llm_load_vocab: control token:    498 '<SPECIAL_498>' is not marked as EOG
# llm_load_vocab: control token:    489 '<SPECIAL_489>' is not marked as EOG
# llm_load_vocab: control token:    767 '<SPECIAL_767>' is not marked as EOG
# llm_load_vocab: control token:    916 '<SPECIAL_916>' is not marked as EOG
# llm_load_vocab: control token:    818 '<SPECIAL_818>' is not marked as EOG
# llm_load_vocab: control token:    894 '<SPECIAL_894>' is not marked as EOG
# llm_load_vocab: control token:    668 '<SPECIAL_668>' is not marked as EOG
# llm_load_vocab: control token:    566 '<SPECIAL_566>' is not marked as EOG
# llm_load_vocab: control token:    898 '<SPECIAL_898>' is not marked as EOG
# llm_load_vocab: control token:    490 '<SPECIAL_490>' is not marked as EOG
# llm_load_vocab: control token:    977 '<SPECIAL_977>' is not marked as EOG
# llm_load_vocab: control token:    900 '<SPECIAL_900>' is not marked as EOG
# llm_load_vocab: control token:    541 '<SPECIAL_541>' is not marked as EOG
# llm_load_vocab: control token:     21 '<SPECIAL_21>' is not marked as EOG
# llm_load_vocab: control token:    787 '<SPECIAL_787>' is not marked as EOG
# llm_load_vocab: control token:    722 '<SPECIAL_722>' is not marked as EOG
# llm_load_vocab: control token:    803 '<SPECIAL_803>' is not marked as EOG
# llm_load_vocab: control token:    210 '<SPECIAL_210>' is not marked as EOG
# llm_load_vocab: control token:    205 '<SPECIAL_205>' is not marked as EOG
# llm_load_vocab: control token:    485 '<SPECIAL_485>' is not marked as EOG
# llm_load_vocab: control token:     40 '<SPECIAL_40>' is not marked as EOG
# llm_load_vocab: control token:     57 '<SPECIAL_57>' is not marked as EOG
# llm_load_vocab: control token:    115 '<SPECIAL_115>' is not marked as EOG
# llm_load_vocab: control token:    798 '<SPECIAL_798>' is not marked as EOG
# llm_load_vocab: control token:    700 '<SPECIAL_700>' is not marked as EOG
# llm_load_vocab: control token:    961 '<SPECIAL_961>' is not marked as EOG
# llm_load_vocab: control token:    101 '<SPECIAL_101>' is not marked as EOG
# llm_load_vocab: control token:    279 '<SPECIAL_279>' is not marked as EOG
# llm_load_vocab: control token:    139 '<SPECIAL_139>' is not marked as EOG
# llm_load_vocab: control token:    903 '<SPECIAL_903>' is not marked as EOG
# llm_load_vocab: control token:    625 '<SPECIAL_625>' is not marked as EOG
# llm_load_vocab: control token:    147 '<SPECIAL_147>' is not marked as EOG
# llm_load_vocab: control token:    837 '<SPECIAL_837>' is not marked as EOG
# llm_load_vocab: control token:    438 '<SPECIAL_438>' is not marked as EOG
# llm_load_vocab: control token:    500 '<SPECIAL_500>' is not marked as EOG
# llm_load_vocab: control token:    371 '<SPECIAL_371>' is not marked as EOG
# llm_load_vocab: control token:     31 '<SPECIAL_31>' is not marked as EOG
# llm_load_vocab: control token:     27 '<SPECIAL_27>' is not marked as EOG
# llm_load_vocab: control token:    948 '<SPECIAL_948>' is not marked as EOG
# llm_load_vocab: control token:     72 '<SPECIAL_72>' is not marked as EOG
# llm_load_vocab: control token:     53 '<SPECIAL_53>' is not marked as EOG
# llm_load_vocab: control token:     70 '<SPECIAL_70>' is not marked as EOG
# llm_load_vocab: control token:    737 '<SPECIAL_737>' is not marked as EOG
# llm_load_vocab: control token:    864 '<SPECIAL_864>' is not marked as EOG
# llm_load_vocab: control token:    623 '<SPECIAL_623>' is not marked as EOG
# llm_load_vocab: control token:    421 '<SPECIAL_421>' is not marked as EOG
# llm_load_vocab: control token:    431 '<SPECIAL_431>' is not marked as EOG
# llm_load_vocab: control token:    589 '<SPECIAL_589>' is not marked as EOG
# llm_load_vocab: control token:    926 '<SPECIAL_926>' is not marked as EOG
# llm_load_vocab: control token:    743 '<SPECIAL_743>' is not marked as EOG
# llm_load_vocab: control token:    484 '<SPECIAL_484>' is not marked as EOG
# llm_load_vocab: control token:    721 '<SPECIAL_721>' is not marked as EOG
# llm_load_vocab: control token:    940 '<SPECIAL_940>' is not marked as EOG
# llm_load_vocab: control token:    971 '<SPECIAL_971>' is not marked as EOG
# llm_load_vocab: control token:    136 '<SPECIAL_136>' is not marked as EOG
# llm_load_vocab: control token:    445 '<SPECIAL_445>' is not marked as EOG
# llm_load_vocab: control token:    142 '<SPECIAL_142>' is not marked as EOG
# llm_load_vocab: control token:    934 '<SPECIAL_934>' is not marked as EOG
# llm_load_vocab: control token:    316 '<SPECIAL_316>' is not marked as EOG
# llm_load_vocab: control token:    690 '<SPECIAL_690>' is not marked as EOG
# llm_load_vocab: control token:    887 '<SPECIAL_887>' is not marked as EOG
# llm_load_vocab: control token:    531 '<SPECIAL_531>' is not marked as EOG
# llm_load_vocab: control token:    482 '<SPECIAL_482>' is not marked as EOG
# llm_load_vocab: control token:    560 '<SPECIAL_560>' is not marked as EOG
# llm_load_vocab: control token:    333 '<SPECIAL_333>' is not marked as EOG
# llm_load_vocab: control token:    574 '<SPECIAL_574>' is not marked as EOG
# llm_load_vocab: control token:    734 '<SPECIAL_734>' is not marked as EOG
# llm_load_vocab: control token:    491 '<SPECIAL_491>' is not marked as EOG
# llm_load_vocab: control token:    199 '<SPECIAL_199>' is not marked as EOG
# llm_load_vocab: control token:    449 '<SPECIAL_449>' is not marked as EOG
# llm_load_vocab: control token:    704 '<SPECIAL_704>' is not marked as EOG
# llm_load_vocab: control token:    618 '<SPECIAL_618>' is not marked as EOG
# llm_load_vocab: control token:    516 '<SPECIAL_516>' is not marked as EOG
# llm_load_vocab: control token:    661 '<SPECIAL_661>' is not marked as EOG
# llm_load_vocab: control token:    459 '<SPECIAL_459>' is not marked as EOG
# llm_load_vocab: control token:    134 '<SPECIAL_134>' is not marked as EOG
# llm_load_vocab: control token:    708 '<SPECIAL_708>' is not marked as EOG
# llm_load_vocab: control token:    426 '<SPECIAL_426>' is not marked as EOG
# llm_load_vocab: control token:    727 '<SPECIAL_727>' is not marked as EOG
# llm_load_vocab: control token:    506 '<SPECIAL_506>' is not marked as EOG
# llm_load_vocab: control token:    265 '<SPECIAL_265>' is not marked as EOG
# llm_load_vocab: control token:    861 '<SPECIAL_861>' is not marked as EOG
# llm_load_vocab: control token:    988 '<SPECIAL_988>' is not marked as EOG
# llm_load_vocab: control token:    189 '<SPECIAL_189>' is not marked as EOG
# llm_load_vocab: control token:    367 '<SPECIAL_367>' is not marked as EOG
# llm_load_vocab: control token:    118 '<SPECIAL_118>' is not marked as EOG
# llm_load_vocab: control token:    526 '<SPECIAL_526>' is not marked as EOG
# llm_load_vocab: control token:    527 '<SPECIAL_527>' is not marked as EOG
# llm_load_vocab: control token:    448 '<SPECIAL_448>' is not marked as EOG
# llm_load_vocab: control token:     86 '<SPECIAL_86>' is not marked as EOG
# llm_load_vocab: control token:    554 '<SPECIAL_554>' is not marked as EOG
# llm_load_vocab: control token:    895 '<SPECIAL_895>' is not marked as EOG
# llm_load_vocab: control token:    608 '<SPECIAL_608>' is not marked as EOG
# llm_load_vocab: control token:    681 '<SPECIAL_681>' is not marked as EOG
# llm_load_vocab: control token:     11 '<pad>' is not marked as EOG
# llm_load_vocab: control token:    403 '<SPECIAL_403>' is not marked as EOG
# llm_load_vocab: control token:    503 '<SPECIAL_503>' is not marked as EOG
# llm_load_vocab: control token:     20 '<SPECIAL_20>' is not marked as EOG
# llm_load_vocab: control token:    797 '<SPECIAL_797>' is not marked as EOG
# llm_load_vocab: control token:    476 '<SPECIAL_476>' is not marked as EOG
# llm_load_vocab: control token:    359 '<SPECIAL_359>' is not marked as EOG
# llm_load_vocab: control token:    909 '<SPECIAL_909>' is not marked as EOG
# llm_load_vocab: control token:    323 '<SPECIAL_323>' is not marked as EOG
# llm_load_vocab: control token:    435 '<SPECIAL_435>' is not marked as EOG
# llm_load_vocab: control token:     43 '<SPECIAL_43>' is not marked as EOG
# llm_load_vocab: control token:    970 '<SPECIAL_970>' is not marked as EOG
# llm_load_vocab: control token:    175 '<SPECIAL_175>' is not marked as EOG
# llm_load_vocab: control token:    300 '<SPECIAL_300>' is not marked as EOG
# llm_load_vocab: control token:    505 '<SPECIAL_505>' is not marked as EOG
# llm_load_vocab: control token:    158 '<SPECIAL_158>' is not marked as EOG
# llm_load_vocab: control token:    890 '<SPECIAL_890>' is not marked as EOG
# llm_load_vocab: control token:    855 '<SPECIAL_855>' is not marked as EOG
# llm_load_vocab: control token:    182 '<SPECIAL_182>' is not marked as EOG
# llm_load_vocab: control token:    312 '<SPECIAL_312>' is not marked as EOG
# llm_load_vocab: control token:    688 '<SPECIAL_688>' is not marked as EOG
# llm_load_vocab: control token:    795 '<SPECIAL_795>' is not marked as EOG
# llm_load_vocab: control token:    883 '<SPECIAL_883>' is not marked as EOG
# llm_load_vocab: control token:    817 '<SPECIAL_817>' is not marked as EOG
# llm_load_vocab: control token:    886 '<SPECIAL_886>' is not marked as EOG
# llm_load_vocab: control token:     50 '<SPECIAL_50>' is not marked as EOG
# llm_load_vocab: control token:    314 '<SPECIAL_314>' is not marked as EOG
# llm_load_vocab: control token:    519 '<SPECIAL_519>' is not marked as EOG
# llm_load_vocab: control token:    989 '<SPECIAL_989>' is not marked as EOG
# llm_load_vocab: control token:    653 '<SPECIAL_653>' is not marked as EOG
# llm_load_vocab: control token:    779 '<SPECIAL_779>' is not marked as EOG
# llm_load_vocab: control token:    377 '<SPECIAL_377>' is not marked as EOG
# llm_load_vocab: control token:    473 '<SPECIAL_473>' is not marked as EOG
# llm_load_vocab: control token:     61 '<SPECIAL_61>' is not marked as EOG
# llm_load_vocab: control token:    165 '<SPECIAL_165>' is not marked as EOG
# llm_load_vocab: control token:    745 '<SPECIAL_745>' is not marked as EOG
# llm_load_vocab: control token:    963 '<SPECIAL_963>' is not marked as EOG
# llm_load_vocab: control token:    775 '<SPECIAL_775>' is not marked as EOG
# llm_load_vocab: control token:    450 '<SPECIAL_450>' is not marked as EOG
# llm_load_vocab: control token:    396 '<SPECIAL_396>' is not marked as EOG
# llm_load_vocab: control token:    587 '<SPECIAL_587>' is not marked as EOG
# llm_load_vocab: control token:    418 '<SPECIAL_418>' is not marked as EOG
# llm_load_vocab: control token:    414 '<SPECIAL_414>' is not marked as EOG
# llm_load_vocab: control token:    859 '<SPECIAL_859>' is not marked as EOG
# llm_load_vocab: control token:    218 '<SPECIAL_218>' is not marked as EOG
# llm_load_vocab: control token:    252 '<SPECIAL_252>' is not marked as EOG
# llm_load_vocab: control token:     55 '<SPECIAL_55>' is not marked as EOG
# llm_load_vocab: control token:    802 '<SPECIAL_802>' is not marked as EOG
# llm_load_vocab: control token:    249 '<SPECIAL_249>' is not marked as EOG
# llm_load_vocab: control token:    130 '<SPECIAL_130>' is not marked as EOG
# llm_load_vocab: control token:     34 '<SPECIAL_34>' is not marked as EOG
# llm_load_vocab: control token:    834 '<SPECIAL_834>' is not marked as EOG
# llm_load_vocab: control token:    660 '<SPECIAL_660>' is not marked as EOG
# llm_load_vocab: control token:    638 '<SPECIAL_638>' is not marked as EOG
# llm_load_vocab: control token:    380 '<SPECIAL_380>' is not marked as EOG
# llm_load_vocab: control token:    411 '<SPECIAL_411>' is not marked as EOG
# llm_load_vocab: control token:     62 '<SPECIAL_62>' is not marked as EOG
# llm_load_vocab: control token:    719 '<SPECIAL_719>' is not marked as EOG
# llm_load_vocab: control token:    340 '<SPECIAL_340>' is not marked as EOG
# llm_load_vocab: control token:    939 '<SPECIAL_939>' is not marked as EOG
# llm_load_vocab: control token:    891 '<SPECIAL_891>' is not marked as EOG
# llm_load_vocab: control token:    184 '<SPECIAL_184>' is not marked as EOG
# llm_load_vocab: control token:    714 '<SPECIAL_714>' is not marked as EOG
# llm_load_vocab: control token:    794 '<SPECIAL_794>' is not marked as EOG
# llm_load_vocab: control token:    736 '<SPECIAL_736>' is not marked as EOG
# llm_load_vocab: control token:    509 '<SPECIAL_509>' is not marked as EOG
# llm_load_vocab: control token:    983 '<SPECIAL_983>' is not marked as EOG
# llm_load_vocab: control token:    862 '<SPECIAL_862>' is not marked as EOG
# llm_load_vocab: control token:    829 '<SPECIAL_829>' is not marked as EOG
# llm_load_vocab: control token:    925 '<SPECIAL_925>' is not marked as EOG
# llm_load_vocab: control token:    698 '<SPECIAL_698>' is not marked as EOG
# llm_load_vocab: control token:    451 '<SPECIAL_451>' is not marked as EOG
# llm_load_vocab: control token:    570 '<SPECIAL_570>' is not marked as EOG
# llm_load_vocab: control token:    214 '<SPECIAL_214>' is not marked as EOG
# llm_load_vocab: control token:    144 '<SPECIAL_144>' is not marked as EOG
# llm_load_vocab: control token:    561 '<SPECIAL_561>' is not marked as EOG
# llm_load_vocab: control token:    582 '<SPECIAL_582>' is not marked as EOG
# llm_load_vocab: control token:    523 '<SPECIAL_523>' is not marked as EOG
# llm_load_vocab: control token:     65 '<SPECIAL_65>' is not marked as EOG
# llm_load_vocab: control token:    311 '<SPECIAL_311>' is not marked as EOG
# llm_load_vocab: control token:    693 '<SPECIAL_693>' is not marked as EOG
# llm_load_vocab: control token:    857 '<SPECIAL_857>' is not marked as EOG
# llm_load_vocab: control token:    513 '<SPECIAL_513>' is not marked as EOG
# llm_load_vocab: control token:    271 '<SPECIAL_271>' is not marked as EOG
# llm_load_vocab: control token:    919 '<SPECIAL_919>' is not marked as EOG
# llm_load_vocab: control token:    720 '<SPECIAL_720>' is not marked as EOG
# llm_load_vocab: control token:    542 '<SPECIAL_542>' is not marked as EOG
# llm_load_vocab: control token:    594 '<SPECIAL_594>' is not marked as EOG
# llm_load_vocab: control token:    338 '<SPECIAL_338>' is not marked as EOG
# llm_load_vocab: control token:     32 '<SPECIAL_32>' is not marked as EOG
# llm_load_vocab: control token:    955 '<SPECIAL_955>' is not marked as EOG
# llm_load_vocab: control token:    969 '<SPECIAL_969>' is not marked as EOG
# llm_load_vocab: control token:    460 '<SPECIAL_460>' is not marked as EOG
# llm_load_vocab: control token:    518 '<SPECIAL_518>' is not marked as EOG
# llm_load_vocab: control token:    588 '<SPECIAL_588>' is not marked as EOG
# llm_load_vocab: control token:    701 '<SPECIAL_701>' is not marked as EOG
# llm_load_vocab: control token:    319 '<SPECIAL_319>' is not marked as EOG
# llm_load_vocab: control token:    320 '<SPECIAL_320>' is not marked as EOG
# llm_load_vocab: control token:    233 '<SPECIAL_233>' is not marked as EOG
# llm_load_vocab: control token:    277 '<SPECIAL_277>' is not marked as EOG
# llm_load_vocab: control token:    585 '<SPECIAL_585>' is not marked as EOG
# llm_load_vocab: control token:    213 '<SPECIAL_213>' is not marked as EOG
# llm_load_vocab: control token:    599 '<SPECIAL_599>' is not marked as EOG
# llm_load_vocab: control token:    291 '<SPECIAL_291>' is not marked as EOG
# llm_load_vocab: control token:    583 '<SPECIAL_583>' is not marked as EOG
# llm_load_vocab: control token:    160 '<SPECIAL_160>' is not marked as EOG
# llm_load_vocab: control token:    109 '<SPECIAL_109>' is not marked as EOG
# llm_load_vocab: control token:    164 '<SPECIAL_164>' is not marked as EOG
# llm_load_vocab: control token:    436 '<SPECIAL_436>' is not marked as EOG
# llm_load_vocab: control token:    461 '<SPECIAL_461>' is not marked as EOG
# llm_load_vocab: control token:    982 '<SPECIAL_982>' is not marked as EOG
# llm_load_vocab: control token:    621 '<SPECIAL_621>' is not marked as EOG
# llm_load_vocab: control token:    303 '<SPECIAL_303>' is not marked as EOG
# llm_load_vocab: control token:    207 '<SPECIAL_207>' is not marked as EOG
# llm_load_vocab: control token:    654 '<SPECIAL_654>' is not marked as EOG
# llm_load_vocab: control token:    868 '<SPECIAL_868>' is not marked as EOG
# llm_load_vocab: control token:    437 '<SPECIAL_437>' is not marked as EOG
# llm_load_vocab: control token:    641 '<SPECIAL_641>' is not marked as EOG
# llm_load_vocab: control token:    200 '<SPECIAL_200>' is not marked as EOG
# llm_load_vocab: control token:    741 '<SPECIAL_741>' is not marked as EOG
# llm_load_vocab: control token:     18 '[/SYSTEM_PROMPT]' is not marked as EOG
# llm_load_vocab: control token:    738 '<SPECIAL_738>' is not marked as EOG
# llm_load_vocab: control token:    786 '<SPECIAL_786>' is not marked as EOG
# llm_load_vocab: control token:     82 '<SPECIAL_82>' is not marked as EOG
# llm_load_vocab: control token:    234 '<SPECIAL_234>' is not marked as EOG
# llm_load_vocab: control token:    563 '<SPECIAL_563>' is not marked as EOG
# llm_load_vocab: control token:    358 '<SPECIAL_358>' is not marked as EOG
# llm_load_vocab: control token:    497 '<SPECIAL_497>' is not marked as EOG
# llm_load_vocab: control token:    296 '<SPECIAL_296>' is not marked as EOG
# llm_load_vocab: control token:    652 '<SPECIAL_652>' is not marked as EOG
# llm_load_vocab: control token:    756 '<SPECIAL_756>' is not marked as EOG
# llm_load_vocab: control token:    170 '<SPECIAL_170>' is not marked as EOG
# llm_load_vocab: control token:    495 '<SPECIAL_495>' is not marked as EOG
# llm_load_vocab: control token:    176 '<SPECIAL_176>' is not marked as EOG
# llm_load_vocab: control token:     89 '<SPECIAL_89>' is not marked as EOG
# llm_load_vocab: control token:    724 '<SPECIAL_724>' is not marked as EOG
# llm_load_vocab: control token:    251 '<SPECIAL_251>' is not marked as EOG
# llm_load_vocab: control token:    238 '<SPECIAL_238>' is not marked as EOG
# llm_load_vocab: control token:    913 '<SPECIAL_913>' is not marked as EOG
# llm_load_vocab: control token:    766 '<SPECIAL_766>' is not marked as EOG
# llm_load_vocab: control token:    826 '<SPECIAL_826>' is not marked as EOG
# llm_load_vocab: control token:    547 '<SPECIAL_547>' is not marked as EOG
# llm_load_vocab: control token:    374 '<SPECIAL_374>' is not marked as EOG
# llm_load_vocab: control token:    514 '<SPECIAL_514>' is not marked as EOG
# llm_load_vocab: control token:    950 '<SPECIAL_950>' is not marked as EOG
# llm_load_vocab: control token:    598 '<SPECIAL_598>' is not marked as EOG
# llm_load_vocab: control token:    850 '<SPECIAL_850>' is not marked as EOG
# llm_load_vocab: control token:    908 '<SPECIAL_908>' is not marked as EOG
# llm_load_vocab: control token:    517 '<SPECIAL_517>' is not marked as EOG
# llm_load_vocab: control token:    679 '<SPECIAL_679>' is not marked as EOG
# llm_load_vocab: control token:    578 '<SPECIAL_578>' is not marked as EOG
# llm_load_vocab: control token:     75 '<SPECIAL_75>' is not marked as EOG
# llm_load_vocab: control token:    462 '<SPECIAL_462>' is not marked as EOG
# llm_load_vocab: control token:    456 '<SPECIAL_456>' is not marked as EOG
# llm_load_vocab: control token:    979 '<SPECIAL_979>' is not marked as EOG
# llm_load_vocab: control token:    446 '<SPECIAL_446>' is not marked as EOG
# llm_load_vocab: control token:    917 '<SPECIAL_917>' is not marked as EOG
# llm_load_vocab: control token:    549 '<SPECIAL_549>' is not marked as EOG
# llm_load_vocab: control token:    183 '<SPECIAL_183>' is not marked as EOG
# llm_load_vocab: control token:    424 '<SPECIAL_424>' is not marked as EOG
# llm_load_vocab: control token:    419 '<SPECIAL_419>' is not marked as EOG
# llm_load_vocab: control token:    413 '<SPECIAL_413>' is not marked as EOG
# llm_load_vocab: control token:    478 '<SPECIAL_478>' is not marked as EOG
# llm_load_vocab: control token:    398 '<SPECIAL_398>' is not marked as EOG
# llm_load_vocab: control token:    386 '<SPECIAL_386>' is not marked as EOG
# llm_load_vocab: control token:    440 '<SPECIAL_440>' is not marked as EOG
# llm_load_vocab: control token:    202 '<SPECIAL_202>' is not marked as EOG
# llm_load_vocab: control token:    747 '<SPECIAL_747>' is not marked as EOG
# llm_load_vocab: control token:    825 '<SPECIAL_825>' is not marked as EOG
# llm_load_vocab: control token:    997 '<SPECIAL_997>' is not marked as EOG
# llm_load_vocab: control token:    369 '<SPECIAL_369>' is not marked as EOG
# llm_load_vocab: control token:    696 '<SPECIAL_696>' is not marked as EOG
# llm_load_vocab: control token:    512 '<SPECIAL_512>' is not marked as EOG
# llm_load_vocab: control token:    349 '<SPECIAL_349>' is not marked as EOG
# llm_load_vocab: control token:    985 '<SPECIAL_985>' is not marked as EOG
# llm_load_vocab: control token:    337 '<SPECIAL_337>' is not marked as EOG
# llm_load_vocab: control token:    135 '<SPECIAL_135>' is not marked as EOG
# llm_load_vocab: control token:    283 '<SPECIAL_283>' is not marked as EOG
# llm_load_vocab: control token:    776 '<SPECIAL_776>' is not marked as EOG
# llm_load_vocab: control token:    327 '<SPECIAL_327>' is not marked as EOG
# llm_load_vocab: control token:    610 '<SPECIAL_610>' is not marked as EOG
# llm_load_vocab: control token:    752 '<SPECIAL_752>' is not marked as EOG
# llm_load_vocab: control token:    510 '<SPECIAL_510>' is not marked as EOG
# llm_load_vocab: control token:     92 '<SPECIAL_92>' is not marked as EOG
# llm_load_vocab: control token:     69 '<SPECIAL_69>' is not marked as EOG
# llm_load_vocab: control token:    703 '<SPECIAL_703>' is not marked as EOG
# llm_load_vocab: control token:    284 '<SPECIAL_284>' is not marked as EOG
# llm_load_vocab: control token:    325 '<SPECIAL_325>' is not marked as EOG
# llm_load_vocab: control token:    228 '<SPECIAL_228>' is not marked as EOG
# llm_load_vocab: control token:    355 '<SPECIAL_355>' is not marked as EOG
# llm_load_vocab: control token:    389 '<SPECIAL_389>' is not marked as EOG
# llm_load_vocab: control token:    458 '<SPECIAL_458>' is not marked as EOG
# llm_load_vocab: control token:    264 '<SPECIAL_264>' is not marked as EOG
# llm_load_vocab: control token:    335 '<SPECIAL_335>' is not marked as EOG
# llm_load_vocab: control token:    181 '<SPECIAL_181>' is not marked as EOG
# llm_load_vocab: control token:    263 '<SPECIAL_263>' is not marked as EOG
# llm_load_vocab: control token:    671 '<SPECIAL_671>' is not marked as EOG
# llm_load_vocab: control token:     63 '<SPECIAL_63>' is not marked as EOG
# llm_load_vocab: control token:    261 '<SPECIAL_261>' is not marked as EOG
# llm_load_vocab: control token:    122 '<SPECIAL_122>' is not marked as EOG
# llm_load_vocab: control token:     90 '<SPECIAL_90>' is not marked as EOG
# llm_load_vocab: control token:    944 '<SPECIAL_944>' is not marked as EOG
# llm_load_vocab: control token:    760 '<SPECIAL_760>' is not marked as EOG
# llm_load_vocab: control token:    956 '<SPECIAL_956>' is not marked as EOG
# llm_load_vocab: control token:    692 '<SPECIAL_692>' is not marked as EOG
# llm_load_vocab: control token:    400 '<SPECIAL_400>' is not marked as EOG
# llm_load_vocab: control token:     83 '<SPECIAL_83>' is not marked as EOG
# llm_load_vocab: control token:    537 '<SPECIAL_537>' is not marked as EOG
# llm_load_vocab: control token:    959 '<SPECIAL_959>' is not marked as EOG
# llm_load_vocab: control token:    910 '<SPECIAL_910>' is not marked as EOG
# llm_load_vocab: control token:    119 '<SPECIAL_119>' is not marked as EOG
# llm_load_vocab: control token:     66 '<SPECIAL_66>' is not marked as EOG
# llm_load_vocab: control token:     10 '[IMG]' is not marked as EOG
# llm_load_vocab: control token:    285 '<SPECIAL_285>' is not marked as EOG
# llm_load_vocab: control token:    524 '<SPECIAL_524>' is not marked as EOG
# llm_load_vocab: control token:    565 '<SPECIAL_565>' is not marked as EOG
# llm_load_vocab: control token:    744 '<SPECIAL_744>' is not marked as EOG
# llm_load_vocab: control token:    255 '<SPECIAL_255>' is not marked as EOG
# llm_load_vocab: control token:    866 '<SPECIAL_866>' is not marked as EOG
# llm_load_vocab: control token:    538 '<SPECIAL_538>' is not marked as EOG
# llm_load_vocab: control token:    280 '<SPECIAL_280>' is not marked as EOG
# llm_load_vocab: control token:    815 '<SPECIAL_815>' is not marked as EOG
# llm_load_vocab: control token:    204 '<SPECIAL_204>' is not marked as EOG
# llm_load_vocab: control token:    276 '<SPECIAL_276>' is not marked as EOG
# llm_load_vocab: control token:    757 '<SPECIAL_757>' is not marked as EOG
# llm_load_vocab: control token:    475 '<SPECIAL_475>' is not marked as EOG
# llm_load_vocab: control token:    480 '<SPECIAL_480>' is not marked as EOG
# llm_load_vocab: control token:    166 '<SPECIAL_166>' is not marked as EOG
# llm_load_vocab: control token:     45 '<SPECIAL_45>' is not marked as EOG
# llm_load_vocab: control token:    262 '<SPECIAL_262>' is not marked as EOG
# llm_load_vocab: control token:    301 '<SPECIAL_301>' is not marked as EOG
# llm_load_vocab: control token:      2 '</s>' is not marked as EOG
# llm_load_vocab: control token:    580 '<SPECIAL_580>' is not marked as EOG
# llm_load_vocab: control token:    432 '<SPECIAL_432>' is not marked as EOG
# llm_load_vocab: control token:    454 '<SPECIAL_454>' is not marked as EOG
# llm_load_vocab: control token:    107 '<SPECIAL_107>' is not marked as EOG
# llm_load_vocab: control token:     46 '<SPECIAL_46>' is not marked as EOG
# llm_load_vocab: control token:    140 '<SPECIAL_140>' is not marked as EOG
# llm_load_vocab: control token:     14 '[PREFIX]' is not marked as EOG
# llm_load_vocab: control token:    246 '<SPECIAL_246>' is not marked as EOG
# llm_load_vocab: control token:     52 '<SPECIAL_52>' is not marked as EOG
# llm_load_vocab: control token:    295 '<SPECIAL_295>' is not marked as EOG
# llm_load_vocab: control token:    994 '<SPECIAL_994>' is not marked as EOG
# llm_load_vocab: control token:    370 '<SPECIAL_370>' is not marked as EOG
# llm_load_vocab: control token:    831 '<SPECIAL_831>' is not marked as EOG
# llm_load_vocab: control token:    488 '<SPECIAL_488>' is not marked as EOG
# llm_load_vocab: control token:    557 '<SPECIAL_557>' is not marked as EOG
# llm_load_vocab: control token:    124 '<SPECIAL_124>' is not marked as EOG
# llm_load_vocab: control token:    644 '<SPECIAL_644>' is not marked as EOG
# llm_load_vocab: control token:    357 '<SPECIAL_357>' is not marked as EOG
# llm_load_vocab: control token:    492 '<SPECIAL_492>' is not marked as EOG
# llm_load_vocab: control token:    209 '<SPECIAL_209>' is not marked as EOG
# llm_load_vocab: control token:     71 '<SPECIAL_71>' is not marked as EOG
# llm_load_vocab: control token:     19 '[TOOL_CONTENT]' is not marked as EOG
# llm_load_vocab: control token:    562 '<SPECIAL_562>' is not marked as EOG
# llm_load_vocab: control token:     47 '<SPECIAL_47>' is not marked as EOG
# llm_load_vocab: control token:    471 '<SPECIAL_471>' is not marked as EOG
# llm_load_vocab: control token:    486 '<SPECIAL_486>' is not marked as EOG
# llm_load_vocab: control token:    244 '<SPECIAL_244>' is not marked as EOG
# llm_load_vocab: control token:     79 '<SPECIAL_79>' is not marked as EOG
# llm_load_vocab: control token:    171 '<SPECIAL_171>' is not marked as EOG
# llm_load_vocab: control token:    564 '<SPECIAL_564>' is not marked as EOG
# llm_load_vocab: control token:    439 '<SPECIAL_439>' is not marked as EOG
# llm_load_vocab: control token:    120 '<SPECIAL_120>' is not marked as EOG
# llm_load_vocab: control token:    399 '<SPECIAL_399>' is not marked as EOG
# llm_load_vocab: control token:     13 '[IMG_END]' is not marked as EOG
# llm_load_vocab: control token:     49 '<SPECIAL_49>' is not marked as EOG
# llm_load_vocab: control token:    938 '<SPECIAL_938>' is not marked as EOG
# llm_load_vocab: control token:    499 '<SPECIAL_499>' is not marked as EOG
# llm_load_vocab: control token:    382 '<SPECIAL_382>' is not marked as EOG
# llm_load_vocab: control token:    824 '<SPECIAL_824>' is not marked as EOG
# llm_load_vocab: control token:    393 '<SPECIAL_393>' is not marked as EOG
# llm_load_vocab: control token:    584 '<SPECIAL_584>' is not marked as EOG
# llm_load_vocab: control token:    275 '<SPECIAL_275>' is not marked as EOG
# llm_load_vocab: control token:    915 '<SPECIAL_915>' is not marked as EOG
# llm_load_vocab: control token:    699 '<SPECIAL_699>' is not marked as EOG
# llm_load_vocab: control token:    838 '<SPECIAL_838>' is not marked as EOG
# llm_load_vocab: control token:    352 '<SPECIAL_352>' is not marked as EOG
# llm_load_vocab: control token:    871 '<SPECIAL_871>' is not marked as EOG
# llm_load_vocab: control token:    470 '<SPECIAL_470>' is not marked as EOG
# llm_load_vocab: control token:    807 '<SPECIAL_807>' is not marked as EOG
# llm_load_vocab: control token:     68 '<SPECIAL_68>' is not marked as EOG
# llm_load_vocab: control token:    678 '<SPECIAL_678>' is not marked as EOG
# llm_load_vocab: control token:    511 '<SPECIAL_511>' is not marked as EOG
# llm_load_vocab: control token:    892 '<SPECIAL_892>' is not marked as EOG
# llm_load_vocab: control token:    749 '<SPECIAL_749>' is not marked as EOG
# llm_load_vocab: control token:    206 '<SPECIAL_206>' is not marked as EOG
# llm_load_vocab: control token:    710 '<SPECIAL_710>' is not marked as EOG
# llm_load_vocab: control token:    732 '<SPECIAL_732>' is not marked as EOG
# llm_load_vocab: control token:    155 '<SPECIAL_155>' is not marked as EOG
# llm_load_vocab: control token:    247 '<SPECIAL_247>' is not marked as EOG
# llm_load_vocab: control token:    208 '<SPECIAL_208>' is not marked as EOG
# llm_load_vocab: control token:    365 '<SPECIAL_365>' is not marked as EOG
# llm_load_vocab: control token:    321 '<SPECIAL_321>' is not marked as EOG
# llm_load_vocab: control token:    217 '<SPECIAL_217>' is not marked as EOG
# llm_load_vocab: control token:    777 '<SPECIAL_777>' is not marked as EOG
# llm_load_vocab: control token:    640 '<SPECIAL_640>' is not marked as EOG
# llm_load_vocab: control token:    515 '<SPECIAL_515>' is not marked as EOG
# llm_load_vocab: control token:    194 '<SPECIAL_194>' is not marked as EOG
# llm_load_vocab: control token:    378 '<SPECIAL_378>' is not marked as EOG
# llm_load_vocab: control token:    104 '<SPECIAL_104>' is not marked as EOG
# llm_load_vocab: control token:    770 '<SPECIAL_770>' is not marked as EOG
# llm_load_vocab: control token:    479 '<SPECIAL_479>' is not marked as EOG
# llm_load_vocab: control token:    145 '<SPECIAL_145>' is not marked as EOG
# llm_load_vocab: control token:    151 '<SPECIAL_151>' is not marked as EOG
# llm_load_vocab: control token:    854 '<SPECIAL_854>' is not marked as EOG
# llm_load_vocab: control token:    929 '<SPECIAL_929>' is not marked as EOG
# llm_load_vocab: control token:    156 '<SPECIAL_156>' is not marked as EOG
# llm_load_vocab: control token:    302 '<SPECIAL_302>' is not marked as EOG
# llm_load_vocab: control token:     88 '<SPECIAL_88>' is not marked as EOG
# llm_load_vocab: control token:    305 '<SPECIAL_305>' is not marked as EOG
# llm_load_vocab: control token:    590 '<SPECIAL_590>' is not marked as EOG
# llm_load_vocab: control token:    763 '<SPECIAL_763>' is not marked as EOG
# llm_load_vocab: control token:    178 '<SPECIAL_178>' is not marked as EOG
# llm_load_vocab: control token:    609 '<SPECIAL_609>' is not marked as EOG
# llm_load_vocab: control token:    353 '<SPECIAL_353>' is not marked as EOG
# llm_load_vocab: control token:    379 '<SPECIAL_379>' is not marked as EOG
# llm_load_vocab: control token:    931 '<SPECIAL_931>' is not marked as EOG
# llm_load_vocab: control token:    222 '<SPECIAL_222>' is not marked as EOG
# llm_load_vocab: control token:    870 '<SPECIAL_870>' is not marked as EOG
# llm_load_vocab: control token:    501 '<SPECIAL_501>' is not marked as EOG
# llm_load_vocab: control token:    682 '<SPECIAL_682>' is not marked as EOG
# llm_load_vocab: control token:    126 '<SPECIAL_126>' is not marked as EOG
# llm_load_vocab: control token:    341 '<SPECIAL_341>' is not marked as EOG
# llm_load_vocab: control token:    597 '<SPECIAL_597>' is not marked as EOG
# llm_load_vocab: control token:    705 '<SPECIAL_705>' is not marked as EOG
# llm_load_vocab: control token:    774 '<SPECIAL_774>' is not marked as EOG
# llm_load_vocab: control token:    121 '<SPECIAL_121>' is not marked as EOG
# llm_load_vocab: control token:    230 '<SPECIAL_230>' is not marked as EOG
# llm_load_vocab: control token:     17 '[SYSTEM_PROMPT]' is not marked as EOG
# llm_load_vocab: control token:    848 '<SPECIAL_848>' is not marked as EOG
# llm_load_vocab: control token:    240 '<SPECIAL_240>' is not marked as EOG
# llm_load_vocab: control token:    336 '<SPECIAL_336>' is not marked as EOG
# llm_load_vocab: control token:    274 '<SPECIAL_274>' is not marked as EOG
# llm_load_vocab: control token:    937 '<SPECIAL_937>' is not marked as EOG
# llm_load_vocab: control token:    350 '<SPECIAL_350>' is not marked as EOG
# llm_load_vocab: control token:    535 '<SPECIAL_535>' is not marked as EOG
# llm_load_vocab: control token:    504 '<SPECIAL_504>' is not marked as EOG
# llm_load_vocab: control token:    662 '<SPECIAL_662>' is not marked as EOG
# llm_load_vocab: control token:    141 '<SPECIAL_141>' is not marked as EOG
# llm_load_vocab: control token:    193 '<SPECIAL_193>' is not marked as EOG
# llm_load_vocab: control token:     77 '<SPECIAL_77>' is not marked as EOG
# llm_load_vocab: control token:    999 '<SPECIAL_999>' is not marked as EOG
# llm_load_vocab: control token:    157 '<SPECIAL_157>' is not marked as EOG
# llm_load_vocab: control token:    568 '<SPECIAL_568>' is not marked as EOG
# llm_load_vocab: control token:     39 '<SPECIAL_39>' is not marked as EOG
# llm_load_vocab: control token:    579 '<SPECIAL_579>' is not marked as EOG
# llm_load_vocab: control token:    581 '<SPECIAL_581>' is not marked as EOG
# llm_load_vocab: control token:    324 '<SPECIAL_324>' is not marked as EOG
# llm_load_vocab: control token:    586 '<SPECIAL_586>' is not marked as EOG
# llm_load_vocab: control token:    595 '<SPECIAL_595>' is not marked as EOG
# llm_load_vocab: control token:    602 '<SPECIAL_602>' is not marked as EOG
# llm_load_vocab: control token:    972 '<SPECIAL_972>' is not marked as EOG
# llm_load_vocab: control token:    632 '<SPECIAL_632>' is not marked as EOG
# llm_load_vocab: control token:    634 '<SPECIAL_634>' is not marked as EOG
# llm_load_vocab: control token:    615 '<SPECIAL_615>' is not marked as EOG
# llm_load_vocab: control token:    117 '<SPECIAL_117>' is not marked as EOG
# llm_load_vocab: control token:    221 '<SPECIAL_221>' is not marked as EOG
# llm_load_vocab: control token:    811 '<SPECIAL_811>' is not marked as EOG
# llm_load_vocab: control token:    197 '<SPECIAL_197>' is not marked as EOG
# llm_load_vocab: control token:    457 '<SPECIAL_457>' is not marked as EOG
# llm_load_vocab: control token:    617 '<SPECIAL_617>' is not marked as EOG
# llm_load_vocab: control token:    712 '<SPECIAL_712>' is not marked as EOG
# llm_load_vocab: control token:    839 '<SPECIAL_839>' is not marked as EOG
# llm_load_vocab: control token:    643 '<SPECIAL_643>' is not marked as EOG
# llm_load_vocab: control token:    902 '<SPECIAL_902>' is not marked as EOG
# llm_load_vocab: control token:    553 '<SPECIAL_553>' is not marked as EOG
# llm_load_vocab: control token:    656 '<SPECIAL_656>' is not marked as EOG
# llm_load_vocab: control token:    672 '<SPECIAL_672>' is not marked as EOG
# llm_load_vocab: control token:    773 '<SPECIAL_773>' is not marked as EOG
# llm_load_vocab: control token:    675 '<SPECIAL_675>' is not marked as EOG
# llm_load_vocab: control token:    361 '<SPECIAL_361>' is not marked as EOG
# llm_load_vocab: control token:    683 '<SPECIAL_683>' is not marked as EOG
# llm_load_vocab: control token:    673 '<SPECIAL_673>' is not marked as EOG
# llm_load_vocab: control token:    800 '<SPECIAL_800>' is not marked as EOG
# llm_load_vocab: control token:    691 '<SPECIAL_691>' is not marked as EOG
# llm_load_vocab: control token:    694 '<SPECIAL_694>' is not marked as EOG
# llm_load_vocab: control token:    604 '<SPECIAL_604>' is not marked as EOG
# llm_load_vocab: control token:    717 '<SPECIAL_717>' is not marked as EOG
# llm_load_vocab: control token:    442 '<SPECIAL_442>' is not marked as EOG
# llm_load_vocab: control token:     93 '<SPECIAL_93>' is not marked as EOG
# llm_load_vocab: control token:    129 '<SPECIAL_129>' is not marked as EOG
# llm_load_vocab: control token:    315 '<SPECIAL_315>' is not marked as EOG
# llm_load_vocab: control token:    406 '<SPECIAL_406>' is not marked as EOG
# llm_load_vocab: control token:    987 '<SPECIAL_987>' is not marked as EOG
# llm_load_vocab: control token:    828 '<SPECIAL_828>' is not marked as EOG
# llm_load_vocab: control token:    368 '<SPECIAL_368>' is not marked as EOG
# llm_load_vocab: control token:    904 '<SPECIAL_904>' is not marked as EOG
# llm_load_vocab: control token:    930 '<SPECIAL_930>' is not marked as EOG
# llm_load_vocab: control token:    317 '<SPECIAL_317>' is not marked as EOG
# llm_load_vocab: control token:    792 '<SPECIAL_792>' is not marked as EOG
# llm_load_vocab: control token:     91 '<SPECIAL_91>' is not marked as EOG
# llm_load_vocab: control token:    814 '<SPECIAL_814>' is not marked as EOG
# llm_load_vocab: control token:    796 '<SPECIAL_796>' is not marked as EOG
# llm_load_vocab: control token:    799 '<SPECIAL_799>' is not marked as EOG
# llm_load_vocab: control token:    664 '<SPECIAL_664>' is not marked as EOG
# llm_load_vocab: control token:    951 '<SPECIAL_951>' is not marked as EOG
# llm_load_vocab: control token:    888 '<SPECIAL_888>' is not marked as EOG
# llm_load_vocab: control token:    806 '<SPECIAL_806>' is not marked as EOG
# llm_load_vocab: control token:    809 '<SPECIAL_809>' is not marked as EOG
# llm_load_vocab: control token:    810 '<SPECIAL_810>' is not marked as EOG
# llm_load_vocab: control token:    819 '<SPECIAL_819>' is not marked as EOG
# llm_load_vocab: control token:    628 '<SPECIAL_628>' is not marked as EOG
# llm_load_vocab: control token:     58 '<SPECIAL_58>' is not marked as EOG
# llm_load_vocab: control token:    392 '<SPECIAL_392>' is not marked as EOG
# llm_load_vocab: control token:    899 '<SPECIAL_899>' is not marked as EOG
# llm_load_vocab: control token:    896 '<SPECIAL_896>' is not marked as EOG
# llm_load_vocab: control token:    612 '<SPECIAL_612>' is not marked as EOG
# llm_load_vocab: control token:    154 '<SPECIAL_154>' is not marked as EOG
# llm_load_vocab: control token:    630 '<SPECIAL_630>' is not marked as EOG
# llm_load_vocab: control token:    856 '<SPECIAL_856>' is not marked as EOG
# llm_load_vocab: control token:    666 '<SPECIAL_666>' is not marked as EOG
# llm_load_vocab: control token:    860 '<SPECIAL_860>' is not marked as EOG
# llm_load_vocab: control token:    863 '<SPECIAL_863>' is not marked as EOG
# llm_load_vocab: control token:    788 '<SPECIAL_788>' is not marked as EOG
# llm_load_vocab: control token:    865 '<SPECIAL_865>' is not marked as EOG
# llm_load_vocab: control token:    872 '<SPECIAL_872>' is not marked as EOG
# llm_load_vocab: control token:    974 '<SPECIAL_974>' is not marked as EOG
# llm_load_vocab: control token:    873 '<SPECIAL_873>' is not marked as EOG
# llm_load_vocab: control token:    543 '<SPECIAL_543>' is not marked as EOG
# llm_load_vocab: control token:      9 '[TOOL_CALLS]' is not marked as EOG
# llm_load_vocab: control token:    665 '<SPECIAL_665>' is not marked as EOG
# llm_load_vocab: control token:    354 '<SPECIAL_354>' is not marked as EOG
# ...
# llm_load_vocab: control token:    830 '<SPECIAL_830>' is not marked as EOG
# llm_load_vocab: control token:    528 '<SPECIAL_528>' is not marked as EOG
# llm_load_vocab: control token:    768 '<SPECIAL_768>' is not marked as EOG
# llm_load_vocab: control token:    591 '<SPECIAL_591>' is not marked as EOG
# llm_load_vocab: control token:    876 '<SPECIAL_876>' is not marked as EOG
# llm_load_vocab: control token:    730 '<SPECIAL_730>' is not marked as EOG
# llm_load_vocab: control token:    571 '<SPECIAL_571>' is not marked as EOG
# llm_load_vocab: control token:    629 '<SPECIAL_629>' is not marked as EOG
# llm_load_vocab: control token:    270 '<SPECIAL_270>' is not marked as EOG
# llm_load_vocab: control token:    742 '<SPECIAL_742>' is not marked as EOG
# llm_load_vocab: control token:    783 '<SPECIAL_783>' is not marked as EOG
# llm_load_vocab: control token:    258 '<SPECIAL_258>' is not marked as EOG
# llm_load_vocab: control token:     67 '<SPECIAL_67>' is not marked as EOG
# llm_load_vocab: control token:    575 '<SPECIAL_575>' is not marked as EOG
# llm_load_vocab: control token:    212 '<SPECIAL_212>' is not marked as EOG
# llm_load_vocab: control token:      3 '[INST]' is not marked as EOG
# llm_load_vocab: control token:    813 '<SPECIAL_813>' is not marked as EOG
# llm_load_vocab: control token:    143 '<SPECIAL_143>' is not marked as EOG
# llm_load_vocab: control token:    149 '<SPECIAL_149>' is not marked as EOG
# llm_load_vocab: control token:    192 '<SPECIAL_192>' is not marked as EOG
# llm_load_vocab: control token:    669 '<SPECIAL_669>' is not marked as EOG
# llm_load_vocab: control token:    648 '<SPECIAL_648>' is not marked as EOG
# llm_load_vocab: control token:    932 '<SPECIAL_932>' is not marked as EOG
# llm_load_vocab: control token:    765 '<SPECIAL_765>' is not marked as EOG
# llm_load_vocab: control token:    113 '<SPECIAL_113>' is not marked as EOG
# llm_load_vocab: control token:     33 '<SPECIAL_33>' is not marked as EOG
# llm_load_vocab: control token:    533 '<SPECIAL_533>' is not marked as EOG
# llm_load_vocab: control token:    103 '<SPECIAL_103>' is not marked as EOG
# llm_load_vocab: control token:    544 '<SPECIAL_544>' is not marked as EOG
# llm_load_vocab: control token:    112 '<SPECIAL_112>' is not marked as EOG
# llm_load_vocab: control token:     56 '<SPECIAL_56>' is not marked as EOG
# llm_load_vocab: control token:    114 '<SPECIAL_114>' is not marked as EOG
# llm_load_vocab: control token:    163 '<SPECIAL_163>' is not marked as EOG
# llm_load_vocab: control token:    108 '<SPECIAL_108>' is not marked as EOG
# llm_load_vocab: control token:    310 '<SPECIAL_310>' is not marked as EOG
# llm_load_vocab: control token:    606 '<SPECIAL_606>' is not marked as EOG
# llm_load_vocab: control token:    410 '<SPECIAL_410>' is not marked as EOG
# llm_load_vocab: control token:    297 '<SPECIAL_297>' is not marked as EOG
# llm_load_vocab: control token:    256 '<SPECIAL_256>' is not marked as EOG
# llm_load_vocab: control token:    851 '<SPECIAL_851>' is not marked as EOG
# llm_load_vocab: control token:    812 '<SPECIAL_812>' is not marked as EOG
# llm_load_vocab: control token:    754 '<SPECIAL_754>' is not marked as EOG
# llm_load_vocab: control token:    225 '<SPECIAL_225>' is not marked as EOG
# llm_load_vocab: control token:    416 '<SPECIAL_416>' is not marked as EOG
# llm_load_vocab: control token:     23 '<SPECIAL_23>' is not marked as EOG
# llm_load_vocab: control token:    733 '<SPECIAL_733>' is not marked as EOG
# llm_load_vocab: control token:    268 '<SPECIAL_268>' is not marked as EOG
# llm_load_vocab: control token:    576 '<SPECIAL_576>' is not marked as EOG
# llm_load_vocab: control token:    596 '<SPECIAL_596>' is not marked as EOG
# llm_load_vocab: control token:    326 '<SPECIAL_326>' is not marked as EOG
# llm_load_vocab: control token:    128 '<SPECIAL_128>' is not marked as EOG
# llm_load_vocab: control token:    507 '<SPECIAL_507>' is not marked as EOG
# llm_load_vocab: control token:    293 '<SPECIAL_293>' is not marked as EOG
# llm_load_vocab: control token:    728 '<SPECIAL_728>' is not marked as EOG
# llm_load_vocab: control token:    292 '<SPECIAL_292>' is not marked as EOG
# llm_load_vocab: control token:    472 '<SPECIAL_472>' is not marked as EOG
# llm_load_vocab: control token:     84 '<SPECIAL_84>' is not marked as EOG
# llm_load_vocab: control token:     99 '<SPECIAL_99>' is not marked as EOG
# llm_load_vocab: control token:    390 '<SPECIAL_390>' is not marked as EOG
# llm_load_vocab: control token:     26 '<SPECIAL_26>' is not marked as EOG
# llm_load_vocab: control token:     74 '<SPECIAL_74>' is not marked as EOG
# llm_load_vocab: control token:    995 '<SPECIAL_995>' is not marked as EOG
# llm_load_vocab: control token:    162 '<SPECIAL_162>' is not marked as EOG
# llm_load_vocab: control token:    877 '<SPECIAL_877>' is not marked as EOG
# llm_load_vocab: control token:    603 '<SPECIAL_603>' is not marked as EOG
# llm_load_vocab: control token:    198 '<SPECIAL_198>' is not marked as EOG
# llm_load_vocab: control token:    657 '<SPECIAL_657>' is not marked as EOG
# llm_load_vocab: control token:    167 '<SPECIAL_167>' is not marked as EOG
# llm_load_vocab: control token:    998 '<SPECIAL_998>' is not marked as EOG
# llm_load_vocab: control token:    789 '<SPECIAL_789>' is not marked as EOG
# llm_load_vocab: control token:     97 '<SPECIAL_97>' is not marked as EOG
# llm_load_vocab: control token:    152 '<SPECIAL_152>' is not marked as EOG
# llm_load_vocab: control token:    725 '<SPECIAL_725>' is not marked as EOG
# llm_load_vocab: control token:    545 '<SPECIAL_545>' is not marked as EOG
# llm_load_vocab: control token:    351 '<SPECIAL_351>' is not marked as EOG
# llm_load_vocab: control token:    345 '<SPECIAL_345>' is not marked as EOG
# llm_load_vocab: control token:    111 '<SPECIAL_111>' is not marked as EOG
# llm_load_vocab: control token:    286 '<SPECIAL_286>' is not marked as EOG
# llm_load_vocab: control token:    331 '<SPECIAL_331>' is not marked as EOG
# llm_load_vocab: control token:    376 '<SPECIAL_376>' is not marked as EOG
# llm_load_vocab: control token:    731 '<SPECIAL_731>' is not marked as EOG
# llm_load_vocab: control token:    935 '<SPECIAL_935>' is not marked as EOG
# llm_load_vocab: control token:    196 '<SPECIAL_196>' is not marked as EOG
# llm_load_vocab: control token:    965 '<SPECIAL_965>' is not marked as EOG
# llm_load_vocab: control token:    469 '<SPECIAL_469>' is not marked as EOG
# llm_load_vocab: control token:    882 '<SPECIAL_882>' is not marked as EOG
# llm_load_vocab: control token:    106 '<SPECIAL_106>' is not marked as EOG
# llm_load_vocab: control token:    322 '<SPECIAL_322>' is not marked as EOG
# llm_load_vocab: control token:    639 '<SPECIAL_639>' is not marked as EOG
# llm_load_vocab: control token:    287 '<SPECIAL_287>' is not marked as EOG
# llm_load_vocab: control token:    853 '<SPECIAL_853>' is not marked as EOG
# llm_load_vocab: control token:    153 '<SPECIAL_153>' is not marked as EOG
# llm_load_vocab: control token:      5 '[AVAILABLE_TOOLS]' is not marked as EOG
# llm_load_vocab: control token:     44 '<SPECIAL_44>' is not marked as EOG
# llm_load_vocab: control token:    313 '<SPECIAL_313>' is not marked as EOG
# llm_load_vocab: control token:    680 '<SPECIAL_680>' is not marked as EOG
# llm_load_vocab: control token:    793 '<SPECIAL_793>' is not marked as EOG
# llm_load_vocab: control token:    702 '<SPECIAL_702>' is not marked as EOG
# llm_load_vocab: control token:    102 '<SPECIAL_102>' is not marked as EOG
# llm_load_vocab: control token:    299 '<SPECIAL_299>' is not marked as EOG
# llm_load_vocab: control token:     76 '<SPECIAL_76>' is not marked as EOG
# llm_load_vocab: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# llm_load_vocab: special tokens cache size = 1000
# llm_load_vocab: token to piece cache size = 0.8498 MB
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = BPE
# llm_load_print_meta: n_vocab          = 131072
# llm_load_print_meta: n_merges         = 269443
# llm_load_print_meta: vocab_only       = 0
# llm_load_print_meta: n_ctx_train      = 131072
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_swa            = 0
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 4
# llm_load_print_meta: n_embd_k_gqa     = 1024
# llm_load_print_meta: n_embd_v_gqa     = 1024
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: f_logit_scale    = 0.0e+00
# llm_load_print_meta: n_ff             = 32768
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: causal attn      = 1
# llm_load_print_meta: pooling type     = 0
# llm_load_print_meta: rope type        = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 1000000000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_ctx_orig_yarn  = 131072
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: ssm_d_conv       = 0
# llm_load_print_meta: ssm_d_inner      = 0
# llm_load_print_meta: ssm_d_state      = 0
# llm_load_print_meta: ssm_dt_rank      = 0
# llm_load_print_meta: ssm_dt_b_c_rms   = 0
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q6_K
# llm_load_print_meta: model params     = 23.57 B
# llm_load_print_meta: model size       = 18.01 GiB (6.56 BPW)
# llm_load_print_meta: general.name     = Mistral-Small-3.1-24B-Instruct-2503
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: PAD token        = 11 '<pad>'
# llm_load_print_meta: LF token         = 1196 'Ä'
# llm_load_print_meta: EOG token        = 2 '</s>'
# llm_load_print_meta: max token length = 150
# llm_load_tensors: tensor 'token_embd.weight' (q6_K) (and 0 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# llm_load_tensors: offloading 40 repeating layers to GPU
# llm_load_tensors: offloading output layer to GPU
# llm_load_tensors: offloaded 41/41 layers to GPU
# llm_load_tensors:        CUDA0 model buffer size = 17917.21 MiB
# llm_load_tensors:   CPU_Mapped model buffer size =   525.00 MiB
# .................................................................................................
# llama_new_context_with_model: n_seq_max     = 1
# llama_new_context_with_model: n_ctx         = 10016
# llama_new_context_with_model: n_ctx_per_seq = 10016
# llama_new_context_with_model: n_batch       = 2048
# llama_new_context_with_model: n_ubatch      = 512
# llama_new_context_with_model: flash_attn    = 0
# llama_new_context_with_model: freq_base     = 1000000000.0
# llama_new_context_with_model: freq_scale    = 1
# llama_new_context_with_model: n_ctx_per_seq (10016) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# llama_kv_cache_init:      CUDA0 KV buffer size =  1565.00 MiB
# llama_new_context_with_model: KV self size  = 1565.00 MiB, K (f16):  782.50 MiB, V (f16):  782.50 MiB
# llama_new_context_with_model:  CUDA_Host  output buffer size =     0.50 MiB
# llama_new_context_with_model:      CUDA0 compute buffer size =   681.57 MiB
# llama_new_context_with_model:  CUDA_Host compute buffer size =    29.57 MiB
# llama_new_context_with_model: graph nodes  = 1286
# llama_new_context_with_model: graph splits = 2
# CUDA : ARCHS = 500,520,530,600,610,620,700,720,750,800,860,870,890,900 | FORCE_MMQ = 1 | USE_GRAPHS = 1 | PEER_MAX_BATCH_SIZE = 128 | CPU : SSE3 = 1 | SSSE3 = 1 | AVX = 1 | AVX2 = 1 | F16C = 1 | FMA = 1 | LLAMAFILE = 1 | OPENMP = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'quantize.imatrix.dataset': 'unsloth_calibration_Mistral-Small-3.1-24B-Instruct-2503.txt', 'general.quantization_version': '2', 'llama.feed_forward_length': '32768', 'general.type': 'model', 'llama.embedding_length': '5120', 'general.size_label': '24B', 'tokenizer.ggml.add_bos_token': 'true', 'general.quantized_by': 'Unsloth', 'tokenizer.ggml.add_eos_token': 'false', 'general.file_type': '18', 'general.finetune': 'Instruct', 'general.repo_url': 'https://huggingface.co/unsloth', 'general.version': '2503', 'quantize.imatrix.file': 'Mistral-Small-3.1-24B-Instruct-2503-GGUF/imatrix_unsloth.dat', 'tokenizer.ggml.add_space_prefix': 'false', 'llama.rope.dimension_count': '128', 'quantize.imatrix.chunks_count': '55', 'llama.context_length': '131072', 'general.basename': 'Mistral-Small-3.1-24B-Instruct-2503', 'tokenizer.ggml.padding_token_id': '11', 'quantize.imatrix.entries_count': '280', 'llama.attention.head_count_kv': '8', 'general.architecture': 'llama', 'general.name': 'Mistral-Small-3.1-24B-Instruct-2503', 'tokenizer.ggml.bos_token_id': '1', 'llama.rope.freq_base': '1000000000.000000', 'llama.block_count': '40', 'llama.attention.head_count': '32', 'llama.attention.key_length': '128', 'llama.attention.value_length': '128', 'tokenizer.ggml.pre': 'tekken', 'llama.vocab_size': '131072', 'tokenizer.ggml.model': 'gpt2', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.unknown_token_id': '0'}
# Using fallback chat format: llama-2
# llama_perf_context_print:        load time =     151.48 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /   247 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   297 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    8932.54 ms /   544 tokens
# Some weights of the model checkpoint at dunzhang/stella_en_400M_v5 were not used when initializing NewModel: {'new.pooler.dense.weight', 'new.pooler.dense.bias'}
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /home/bkantz/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:1072: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Llama.generate: 246 prefix-match hit, remaining 1 prompt tokens to eval
# llama_perf_context_print:        load time =     151.48 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   298 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    8748.53 ms /   299 tokens
# /home/bkantz/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:477: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue: Expected `EntitiesRelations` but got `ConstrainedEntitiesRelations` with value `ConstrainedEntitiesRelati...e='Constraints applied')` - serialized value may not be as expected
#   PydanticSerializationUnexpectedValue: Expected `Candidates` but got `ConstrainedEntitiesRelations` with value `ConstrainedEntitiesRelati...e='Constraints applied')` - serialized value may not be as expected
#   PydanticSerializationUnexpectedValue: Expected `EnrichedEntitiesRelations` but got `ConstrainedEntitiesRelations` with value `ConstrainedEntitiesRelati...e='Constraints applied')` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_json(

# %%
(
    [[ent.type for ent in target_erl.entities]],
    [[ent.type for ent in progress.enriched_relations.entities]],
)
# Out:
# ([['Organisation member', 'stream', 'company']],
#  [['organisation', 'organisation', 'organisation', 'place', 'place']])

# %%
def graph_from_erl(erl: EnrichedEntitiesRelations):
    G = nx.DiGraph()
    for node in erl.entities:
        G.add_node(node.identifier, label=node.type)
    for link in erl.relations:
        G.add_edge(
            link.entity,
            link.target,
            weight=link.link.instance_count,
            label=link.relation,
        )
    return G

# %%
def f1k(y_true, y_pred, k: int = None):
    rel_set = set(y_true)
    # print(rel_set)
    doc_set = set(y_pred[:k])
    tp = len(doc_set.intersection(rel_set))  # docs that are in both -relevant docs
    fp = len(
        doc_set.difference(rel_set)
    )  # docs that are not in relevant set - irrelevant docs (false positiv)
    fn = len(
        rel_set.difference(doc_set)
    )  # relevant docs that are not present in doc set - missing docs
    if tp == 0:
        return 0
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    return 2 * precision * recall / (precision + recall)

# %%
f1_score_ents = f1k(
    [ent.type for ent in target_erl.entities],
    [ent.type for ent in progress.enriched_relations.entities],
)
f1_score_ents
# Out:
# 0

# %%
target_graph = graph_from_erl(target_erl)
retrieved_grap = graph_from_erl(progress.enriched_relations)


def edge_match(a, b):
    return a["label"] == b["label"] if "label" in a and "label" in b else False


def node_match(a, b):
    return a["label"] == b["label"] if "label" in a and "label" in b else False


1 - nx.graph_edit_distance(
    target_graph, retrieved_grap, edge_match=edge_match, node_match=node_match
) / (
    len(target_graph.edges)
    + len(retrieved_grap.edges)
    + len(target_graph.nodes)
    + len(retrieved_grap.nodes)
)
# Out:
# 0.3571428571428571

# %%
def run_eval(query: pd.Series, llm_query: LLMQuery):
    target_erl: EnrichedEntitiesRelations = query["erl"]
    query = query["response"]
    progress = QueryProgress(id="0", max_steps=1, start_time="0")
    llm_query.run_query(query=query, progress=progress)
    f1_score_ents = f1k(
        [ent.type for ent in target_erl.entities],
        [ent.type for ent in progress.enriched_relations.entities],
    )
    target_graph = graph_from_erl(target_erl)
    retrieved_grap = graph_from_erl(progress.enriched_relations)
    edit_distance = 1 - nx.graph_edit_distance(
        target_graph, retrieved_grap, edge_match=edge_match, node_match=node_match
    ) / (
        len(target_graph.edges)
        + len(retrieved_grap.edges)
        + len(target_graph.nodes)
        + len(retrieved_grap.nodes)
    )
    return f1_score_ents, edit_distance


def run_evals(queries: pd.DataFrame, llm_query: LLMQuery):
    results = queries.copy()
    for i, query in tqdm(queries.iterrows(), total=len(queries)):
        f1_score_ents, edit_distance = run_eval(query, llm_query)
        results.loc[i, "f1_score"] = f1_score_ents
        results.loc[i, "edit_distance"] = edit_distance
    return results


for zero_shot in [True, False]:
    print(f"oneshot={zero_shot}")
    query_man = LLMQuery(topic_man, zero_shot=zero_shot)
    results = run_evals(generated_queries, llm_query=query_man)
    results.to_csv(
        f"restuls/eval_results_{'oneshot' if zero_shot else 'zeroshot'}_{topic_man.llm_model_id.replace('/', '-')}.csv"
    )
# Out:
# oneshot=True
#   0%|          | 0/897 [00:00<?, ?it/s]
# Llama.generate: 6 prefix-match hit, remaining 120 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /   120 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   264 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    8165.69 ms /   384 tokens
# Llama.generate: 6 prefix-match hit, remaining 98 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    98 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   325 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    9485.19 ms /   423 tokens
#   0%|          | 1/897 [00:20<5:00:07, 20.10s/it]Llama.generate: 6 prefix-match hit, remaining 92 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    92 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   334 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =   10092.91 ms /   426 tokens
# Llama.generate: 6 prefix-match hit, remaining 70 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    70 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   186 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    5395.70 ms /   256 tokens
#   0%|          | 2/897 [00:37<4:39:40, 18.75s/it]Llama.generate: 6 prefix-match hit, remaining 89 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    89 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   382 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =   11355.57 ms /   471 tokens
# Llama.generate: 6 prefix-match hit, remaining 67 prompt tokens to eval
# llama_perf_context_print:        load time =     308.59 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    67 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   286 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =    8433.32 ms /   353 tokens
#   0%|          | 3/897 [01:00<5:08:17, 20.69s/it]Llama.generate: 6 prefix-match hit, remaining 87 prompt tokens to eval
#   0%|          | 3/897 [01:05<5:25:35, 21.85s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 35
#      33 print(f"oneshot={zero_shot}")
#      34 query_man = LLMQuery(topic_man, zero_shot=zero_shot)
# ---> 35 results = run_evals(generated_queries, llm_query=query_man)
#      36 results.to_csv(
#      37     f"restuls/eval_results_{'oneshot' if zero_shot else 'zeroshot'}_{topic_man.llm_model_id.replace('/', '-')}.csv"
#      38 )
#
# Cell In[11], line 26, in run_evals(queries, llm_query)
#      24 results = queries.copy()
#      25 for i, query in tqdm(queries.iterrows(), total=len(queries)):
# ---> 26     f1_score_ents, edit_distance = run_eval(query, llm_query)
#      27     results.loc[i, "f1_score"] = f1_score_ents
#      28     results.loc[i, "edit_distance"] = edit_distance
#
# Cell In[11], line 5, in run_eval(query, llm_query)
#       3 query = query["response"]
#       4 progress = QueryProgress(id="0", max_steps=1, start_time="0")
# ----> 5 llm_query.run_query(query=query, progress=progress)
#       6 f1_score_ents = f1k(
#       7     [ent.type for ent in target_erl.entities],
#       8     [ent.type for ent in progress.enriched_relations.entities],
#       9 )
#      10 target_graph = graph_from_erl(target_erl)
#
# File ~/cgv/hereditary/onset/backend/llm_query.py:218, in LLMQuery.run_query(self, progress, query)
#     215 progress.message = "Querying entities and relations"
#     216 self.cache[progress.id] = progress
# --> 218 erl = self.query_erl(query)
#     219 progress.progress = 2
#     220 progress.message = "Fetching possible candidates"
#
# File ~/cgv/hereditary/onset/backend/llm_query.py:280, in LLMQuery.query_erl(self, query)
#     273     messages.extend(
#     274         [
#     275             {"role": "user", "content": ERL_PROMPT_EXAMPLE[0]},
#     276             {"role": "assistant", "content": ERL_PROMPT_EXAMPLE[1]},
#     277         ]
#     278     )
#     279 messages.append({"role": "user", "content": query})
# --> 280 response = self.model.create_chat_completion(
#     281     grammar=self.grammar_erl,
#     282     messages=messages,
#     283     max_tokens=-1,
#     284     temperature=self.temperature,
#     285 )
#     286 response_msg = response["choices"][0]["message"]["content"]
#     287 return EntitiesRelations.model_validate_json(response_msg)
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:1998, in Llama.create_chat_completion(self, messages, functions, function_call, tools, tool_choice, temperature, top_p, top_k, min_p, typical_p, stream, stop, seed, response_format, max_tokens, presence_penalty, frequency_penalty, repeat_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, logits_processor, grammar, logit_bias, logprobs, top_logprobs)
#    1960 """Generate a chat completion from a list of messages.
#    1961
#    1962 Args:
#    (...)
#    1991     Generated chat completion or a stream of chat completion chunks.
#    1992 """
#    1993 handler = (
#    1994     self.chat_handler
#    1995     or self._chat_handlers.get(self.chat_format)
#    1996     or llama_chat_format.get_chat_completion_handler(self.chat_format)
#    1997 )
# -> 1998 return handler(
#    1999     llama=self,
#    2000     messages=messages,
#    2001     functions=functions,
#    2002     function_call=function_call,
#    2003     tools=tools,
#    2004     tool_choice=tool_choice,
#    2005     temperature=temperature,
#    2006     top_p=top_p,
#    2007     top_k=top_k,
#    2008     min_p=min_p,
#    2009     typical_p=typical_p,
#    2010     logprobs=logprobs,
#    2011     top_logprobs=top_logprobs,
#    2012     stream=stream,
#    2013     stop=stop,
#    2014     seed=seed,
#    2015     response_format=response_format,
#    2016     max_tokens=max_tokens,
#    2017     presence_penalty=presence_penalty,
#    2018     frequency_penalty=frequency_penalty,
#    2019     repeat_penalty=repeat_penalty,
#    2020     tfs_z=tfs_z,
#    2021     mirostat_mode=mirostat_mode,
#    2022     mirostat_tau=mirostat_tau,
#    2023     mirostat_eta=mirostat_eta,
#    2024     model=model,
#    2025     logits_processor=logits_processor,
#    2026     grammar=grammar,
#    2027     logit_bias=logit_bias,
#    2028 )
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama_chat_format.py:662, in chat_formatter_to_chat_completion_handler.<locals>.chat_completion_handler(llama, messages, functions, function_call, tools, tool_choice, temperature, top_p, top_k, min_p, typical_p, stream, stop, seed, response_format, max_tokens, presence_penalty, frequency_penalty, repeat_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, logits_processor, grammar, logit_bias, logprobs, top_logprobs, **kwargs)
#     657             print(str(e), file=sys.stderr)
#     658         grammar = llama_grammar.LlamaGrammar.from_string(
#     659             llama_grammar.JSON_GBNF, verbose=llama.verbose
#     660         )
# --> 662 completion_or_chunks = llama.create_completion(
#     663     prompt=prompt,
#     664     temperature=temperature,
#     665     top_p=top_p,
#     666     top_k=top_k,
#     667     min_p=min_p,
#     668     typical_p=typical_p,
#     669     logprobs=top_logprobs if logprobs else None,
#     670     stream=stream,
#     671     stop=stop,
#     672     seed=seed,
#     673     max_tokens=max_tokens,
#     674     presence_penalty=presence_penalty,
#     675     frequency_penalty=frequency_penalty,
#     676     repeat_penalty=repeat_penalty,
#     677     tfs_z=tfs_z,
#     678     mirostat_mode=mirostat_mode,
#     679     mirostat_tau=mirostat_tau,
#     680     mirostat_eta=mirostat_eta,
#     681     model=model,
#     682     logits_processor=logits_processor,
#     683     stopping_criteria=stopping_criteria,
#     684     grammar=grammar,
#     685     logit_bias=logit_bias,
#     686 )
#     687 if tool is not None:
#     688     tool_name = tool["function"]["name"]
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:1832, in Llama.create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1830     chunks: Iterator[CreateCompletionStreamResponse] = completion_or_chunks
#    1831     return chunks
# -> 1832 completion: Completion = next(completion_or_chunks)  # type: ignore
#    1833 return completion
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:1317, in Llama._create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1315 finish_reason = "length"
#    1316 multibyte_fix = 0
# -> 1317 for token in self.generate(
#    1318     prompt_tokens,
#    1319     top_k=top_k,
#    1320     top_p=top_p,
#    1321     min_p=min_p,
#    1322     typical_p=typical_p,
#    1323     temp=temperature,
#    1324     tfs_z=tfs_z,
#    1325     mirostat_mode=mirostat_mode,
#    1326     mirostat_tau=mirostat_tau,
#    1327     mirostat_eta=mirostat_eta,
#    1328     frequency_penalty=frequency_penalty,
#    1329     presence_penalty=presence_penalty,
#    1330     repeat_penalty=repeat_penalty,
#    1331     stopping_criteria=stopping_criteria,
#    1332     logits_processor=logits_processor,
#    1333     grammar=grammar,
#    1334 ):
#    1335     if llama_cpp.llama_token_is_eog(self._model.model, token):
#    1336         text = self.detokenize(completion_tokens, prev_tokens=prompt_tokens)
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:911, in Llama.generate(self, tokens, top_k, top_p, min_p, typical_p, temp, repeat_penalty, reset, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, penalize_nl, logits_processor, stopping_criteria, grammar)
#     909 self.eval(tokens)
#     910 while sample_idx < self.n_tokens:
# --> 911     token = self.sample(
#     912         top_k=top_k,
#     913         top_p=top_p,
#     914         min_p=min_p,
#     915         typical_p=typical_p,
#     916         temp=temp,
#     917         repeat_penalty=repeat_penalty,
#     918         frequency_penalty=frequency_penalty,
#     919         presence_penalty=presence_penalty,
#     920         tfs_z=tfs_z,
#     921         mirostat_mode=mirostat_mode,
#     922         mirostat_tau=mirostat_tau,
#     923         mirostat_eta=mirostat_eta,
#     924         logits_processor=logits_processor,
#     925         grammar=grammar,
#     926         penalize_nl=penalize_nl,
#     927         idx=sample_idx,
#     928     )
#     930     sample_idx += 1
#     931     if stopping_criteria is not None and stopping_criteria(
#     932         self._input_ids[: sample_idx], self._scores[sample_idx - self.n_tokens, :]
#     933     ):
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/llama.py:812, in Llama.sample(self, top_k, top_p, min_p, typical_p, temp, repeat_penalty, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_eta, mirostat_tau, penalize_nl, logits_processor, grammar, idx)
#     809 ridx = idx - self.n_tokens if idx is not None else -1
#     811 assert self.ctx is not None
# --> 812 token = self._sampler.sample(self._ctx, ridx)
#     813 if tmp_sampler:
#     814     self._sampler = None
#
# File ~/cgv/hereditary/onset/backend/.venv/lib/python3.12/site-packages/llama_cpp/_internals.py:850, in LlamaSampler.sample(self, ctx, idx)
#     848 def sample(self, ctx: LlamaContext, idx: int) -> int:
#     849     assert self.sampler is not None
# --> 850     return llama_cpp.llama_sampler_sample(self.sampler, ctx.ctx, idx)
#
# KeyboardInterrupt:
