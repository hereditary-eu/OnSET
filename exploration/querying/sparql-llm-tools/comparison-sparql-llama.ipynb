# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

sys.path.insert(0, os.path.abspath("../../../"))
sys.path.append(os.path.abspath("../../../backend"))
sys.path.append(os.path.abspath(""))

# %%
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from backend.ontology import Graph, OntologyManager, OntologyConfig
from backend.datasetmatcher import DatasetManager
from backend.explorative_support import TopicModelling

base_path = "../data"
onto_path = f"{base_path}/hero-ontology/hereditary_clinical.ttl"


# graph = Graph().parse(onto_path, format="turtle")
# graph.bind("bto", "http://www.semanticweb.org/ontologies/2020/3/bto#")

# store = SPARQLStore(
#     "http://localhost:7200/repositories/dpedia",
#     method="POST_FORM",
#     params={"infer": False, "sameAs": False},
# )

# store = SPARQLStore(
#     "http://localhost:3030/dbpedia/query",
#     method="POST_FORM",
#     params={"infer": False, "sameAs": False},
# )
store = SPARQLStore(
    "https://sparql.omabrowser.org/sparql",
    method="GET",
    # params={"infer": False, "sameAs": False},
)
graph = Graph(store=store)

config = OntologyConfig()

ontology_manager = OntologyManager(config, graph)
dataset_manager = DatasetManager(ontology_manager)
dataset_manager.initialise(glob_path="data/datasets/ALS/**/*.csv")

# ontology_manager.load_full_graph()
# Out:
# -- Loading and merging datasets
# 0 datasets loaded

# %%
topic_man = TopicModelling(ontology_manager, conn_str="postgresql+psycopg://postgres:postgres@localhost:5434/onset-uniprot")
print(topic_man.identifier)
topic_man.initialize_topics(force=True, delete_tables=True)
# Out:
# c9bdd3ba4842e291266a5516543e2aa2840e9184f01b65438da44dd0801af623
# Initializing topics
# Enriching classes:   3%|▎         | 6/217 [00:19<10:13,  2.91s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:   3%|▎         | 7/217 [01:35<1:34:05, 26.89s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:   4%|▎         | 8/217 [02:53<2:30:26, 43.19s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:   6%|▌         | 12/217 [04:18<1:07:38, 19.80s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:   7%|▋         | 15/217 [05:45<1:08:19, 20.30s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:   7%|▋         | 16/217 [07:05<2:09:07, 38.54s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:   8%|▊         | 18/217 [08:27<2:00:34, 36.35s/it]
# HTTPError <urlopen error [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)> 1
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 2
# Enriching classes:  10%|▉         | 21/217 [10:44<1:48:17, 33.15s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  11%|█         | 23/217 [12:04<1:47:04, 33.12s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  12%|█▏        | 25/217 [13:26<1:48:34, 33.93s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  12%|█▏        | 27/217 [14:43<1:44:37, 33.04s/it]
# HTTPError <urlopen error [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)> 1
# Enriching classes:  13%|█▎        | 29/217 [15:45<1:31:59, 29.36s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  15%|█▍        | 32/217 [17:06<1:08:55, 22.36s/it]
# HTTPError <urlopen error [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)> 1
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  16%|█▌        | 34/217 [19:16<1:56:46, 38.29s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  17%|█▋        | 36/217 [20:33<1:46:00, 35.14s/it]
# HTTPError <urlopen error [Errno 54] Connection reset by peer> 1
# Enriching classes:  18%|█▊        | 39/217 [21:53<1:11:41, 24.17s/it]
# HTTPError HTTP Error 400: Bad Request 1
# HTTPError HTTP Error 400: Bad Request 2
# HTTPError HTTP Error 400: Bad Request 3
# Traceback (most recent call last):
#   File "/Users/benedikt/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlconnector.py", line 119, in query
#     res = urlopen(
#           ^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 215, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 521, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 630, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 553, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 492, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 745, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 521, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 630, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 559, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 492, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/Users/benedikt/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py", line 639, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/benedikt/tugraz/cgv/hereditary/ontology_provenance/backend/ontology.py", line 222, in outgoing_edges_for
#     self.onto.query(
#   File "/Users/benedikt/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/graph.py", line 1605, in query
#     return self.store.query(
#            ^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlstore.py", line 246, in query
#     return self._query(
#            ^^^^^^^^^^^^
#   File "/Users/benedikt/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlstore.py", line 205, in _query
#     return super(SPARQLStore, self).query(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/benedikt/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlconnector.py", line 128, in query
#     raise ValueError(
# ValueError: You did something wrong formulating either the URI or your SPARQL query
#
# HTTPError HTTP Error 400: Bad Request 1
# HTTPError HTTP Error 400: Bad Request 2
# Enriching classes:  18%|█▊        | 39/217 [21:58<1:40:19, 33.82s/it]
# HTTPError HTTP Error 400: Bad Request 3
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlconnector.py:119, in SPARQLConnector.query(self, query, default_graph, named_graph)
#     118 try:
# --> 119     res = urlopen(
#     120         Request(self.query_endpoint + qsa, headers=args["headers"]),
#     121         timeout=self.timeout,
#     122     )
#     123     break
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:553, in OpenerDirector.error(self, proto, *args)
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     491 func = getattr(handler, meth_name)
# --> 492 result = func(*args)
#     493 if result is not None:
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:559, in OpenerDirector.error(self, proto, *args)
#     558 args = (dict, 'default', 'http_error_default') + orig_args
# --> 559 return self._call_chain(*args)
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     491 func = getattr(handler, meth_name)
# --> 492 result = func(*args)
#     493 if result is not None:
#
# File ~/.local/share/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/urllib/request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 topic_man = TopicModelling(ontology_manager, conn_str="postgresql+psycopg://postgres:postgres@localhost:5434/onset-uniprot")
#       2 print(topic_man.identifier)
# ----> 3 topic_man.initialize_topics(force=True, delete_tables=True)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/explorative_support.py:196, in TopicModelling.initialize_topics(self, force, delete_tables)
#     193     session.commit()
#     195 # embed first, then model to make sure subjects are available for topics
# --> 196 self.__embed_relations()
#     197 self.model_topics()
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/explorative_support.py:454, in TopicModelling.__embed_relations(self)
#     444     def __embed_relations(self):
#     445         all_classes = self.oman.q_to_df(
#     446             """
#     447 SELECT ?s
#    (...)
#     451 """
#     452         )[0].to_list()
#     453         all_classes = {
# --> 454             c: self.oman.enrich_subject(c, load_properties=True)
#     455             for c in tqdm(all_classes, desc="Enriching classes")
#     456         }
#     458         with Session(self.engine) as session:
#     459             session.execute(text("SET CONSTRAINTS ALL DEFERRED"))
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/ontology.py:341, in OntologyManager.enrich_subject(self, cls, subject_type, load_properties)
#     328 outgoing_edges = self.outgoing_edges_for(
#     329     col_ref,
#     330     edges=["rdfs:label", "rdfs:range", "rdfs:subPropertyOf", "rdfs:subClassOf"],
#     331 )
#     332 label_prop: Property = outgoing_edges.get(
#     333     "rdfs:label",
#     334     Property(values=[PropertyValue(value=col_ref, label=None)]),
#     335 )
#     336 subject = Subject(
#     337     subject_id=col_ref,
#     338     label=label_prop.first_value(),
#     339     spos=outgoing_edges,
#     340     subject_type=subject_type,
# --> 341     instance_count=self.instance_count(col_ref),
#     342     # refcount=refs,
#     343 )
#     344 if load_properties:
#     345     subject.properties = {
#     346         prop_type: self.properties_for(col_ref, property_type=prop_type)
#     347         for prop_type in self.config.property_types
#     348     }
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/ontology.py:388, in OntologyManager.instance_count(self, cls)
#     387 def instance_count(self, cls: str):
# --> 388     return self.q_to_df(
#     389         f"SELECT DISTINCT (COUNT(?s) as ?count) WHERE {{?s a {cls}}}"
#     390     )[0][0].value
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/backend/ontology.py:60, in OntologyManager.q_to_df(self, q)
#      59 def q_to_df(self, q: str):
# ---> 60     results = list(self.onto.query(q))
#      61     # for r in results:
#      62     #     for t in r:
#      63     #         if isinstance(t, URIRef):
#    (...)
#      68     #     lambda x: x.n3(self.onto.namespace_manager) if hasattr(x, "n3") else x
#      69     # )
#      70     return pd.DataFrame(results)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/graph.py:1605, in Graph.query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1603 if hasattr(self.store, "query") and use_store_provided:
#    1604     try:
# -> 1605         return self.store.query(
#    1606             query_object,
#    1607             initNs,
#    1608             initBindings,
#    1609             query_graph,
#    1610             **kwargs,
#    1611         )
#    1612     except NotImplementedError:
#    1613         pass  # store has no own implementation
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlstore.py:246, in SPARQLStore.query(self, query, initNs, initBindings, queryGraph, DEBUG)
#     240     # VALUES was added to SPARQL 1.1 on 2012/07/24
#     241     query += "\nVALUES ( %s )\n{ ( %s ) }\n" % (
#     242         " ".join("?" + str(x) for x in v),
#     243         " ".join(self.node_to_sparql(initBindings[x]) for x in v),
#     244     )
# --> 246 return self._query(
#     247     query, default_graph=queryGraph if self._is_contextual(queryGraph) else None
#     248 )
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlstore.py:205, in SPARQLStore._query(self, *args, **kwargs)
#     202 def _query(self, *args: Any, **kwargs: Any) -> Result:
#     203     self._queries += 1
# --> 205     return super(SPARQLStore, self).query(*args, **kwargs)
#
# File ~/tugraz/cgv/hereditary/ontology_provenance/rdflib/rdflib/plugins/stores/sparqlconnector.py:128, in SPARQLConnector.query(self, query, default_graph, named_graph)
#     126             print("HTTPError", e, trials)
#     127             if trials == self.retries:
# --> 128                 raise ValueError(
#     129                     "You did something wrong formulating either the URI or your SPARQL query"
#     130                 )
#     131 elif self.method == "POST":
#     132     args["headers"].update({"Content-Type": "application/sparql-query"})
#
# ValueError: You did something wrong formulating either the URI or your SPARQL query

# %%
from sparql_llm import SparqlExamplesLoader, SparqlVoidShapesLoader

ex_loader = SparqlExamplesLoader("http://localhost:7012/")
docs = ex_loader.load()
print(len(docs))
print(docs[0].metadata)
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 docs = ex_loader.load()
#       5 print(len(docs))
# ----> 6 print(docs[0].metadata)
#
# IndexError: list index out of range

# %%
void_loader = SparqlVoidShapesLoader("http://localhost:7012/")
voids = void_loader.load()
print(len(voids))
print(voids[0].metadata)
# Out:
# Could not retrieve VoID description for endpoint http://localhost:7012/: No VoID description found in the endpoint
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 voids = void_loader.load()
#       3 print(len(voids))
# ----> 4 print(voids[0].metadata)
#
# IndexError: list index out of range
