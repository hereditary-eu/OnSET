# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tikzplotlib


plt.rc("text", usetex=True)
plt.rc("text.latex", preamble="""\\usepackage{amsmath}""")
plt.style.use("fivethirtyeight")
# set background color to white of the figure and axes
plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["axes.facecolor"] = "white"

# def tikzplotlib_fix_ncols(obj):
#     """
#     workaround for matplotlib 3.6 renamed legend's _ncol to _ncols, which breaks tikzplotlib
#     """
#     if hasattr(obj, "_ncols"):
#         obj._ncol = obj._ncols
#     for child in obj.get_children():
#         tikzplotlib_fix_ncols(child)


# https://github.com/nschloe/tikzplotlib/issues/567
# from matplotlib.lines import Line2D
# from matplotlib.legend import Legend

# Line2D._us_dashSeq = property(lambda self: self._dash_pattern[1])
# Line2D._us_dashOffset = property(lambda self: self._dash_pattern[0])
# Legend._ncol = property(lambda self: self._ncols)

import seaborn as sns

palette = sns.color_palette('pastel').as_hex()
def adjust_lightness(color, amount=1.1):
    import matplotlib.colors as mc
    import colorsys

    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], np.maximum(0, np.minimum(1, amount * c[1])), c[2])

plt.rcParams.update({'errorbar.capsize': 2})

# %%
df=pd.read_csv("./private/OnSET SUS (responses).csv")
df
# Out:
#     User ID User display name                  Timestamp Participant ID  \
# 0       NaN    Anonymous user  2025-06-03T10:42:18+02:00           IT28
# 1       NaN    Anonymous user  2025-06-03T12:00:40+02:00           SR01
# 2       NaN    Anonymous user  2025-06-03T14:57:47+02:00           SI01
# 3       NaN    Anonymous user  2025-06-04T13:52:37+02:00           RR15
# 4       NaN    Anonymous user  2025-06-07T16:31:02+02:00           MH02
# 5       NaN    Anonymous user  2025-06-17T15:55:44+02:00           PA25
# 6       NaN    Anonymous user  2025-06-18T11:13:33+02:00           JK17
# 7       NaN    Anonymous user  2025-06-23T11:08:24+02:00           SR17
# 8       NaN    Anonymous user  2025-06-23T13:04:47+02:00           MT23
# 9       NaN    Anonymous user  2025-06-27T10:49:14+02:00           Mr15
# 10      NaN    Anonymous user  2025-07-02T11:17:07+02:00           TE02
#
#     I think that I would like to use OnSET frequently.  \
# 0                                                   3
# 1                                                   4
# 2                               1 - Strongly Disagree
# 3                                                   4
# 4                                                   3
# 5                                                   4
# 6                                                   4
# 7                                                   4
# 8                                                   4
# 9                                                   4
# 10                                                  3
#
#     I found OnSET unnecessarily complex. I thought OnSET was easy to use.  \
# 0                  1 - Strongly Disagree                                4
# 1                                      2                                4
# 2                  1 - Strongly Disagree                                2
# 3                  1 - Strongly Disagree                                4
# 4                                      2                                4
# 5                                      3                                4
# 6                                      2                                3
# 7                  1 - Strongly Disagree               5 - Strongly agree
# 8                     5 - Strongly agree               5 - Strongly agree
# 9                  1 - Strongly Disagree                                4
# 10                                     2                                4
#
#    I think that I would need the support of a technical person to be able to use OnSET.  \
# 0                                                   4
# 1                               1 - Strongly Disagree
# 2                               1 - Strongly Disagree
# 3                               1 - Strongly Disagree
# 4                                                   3
# 5                                                   4
# 6                                                   4
# 7                                                   3
# 8                                  5 - Strongly agree
# 9                                                   3
# 10                                                  2
#
#    I found the various functions in OnSET were well integrated.  \
# 0                                                   3
# 1                                  5 - Strongly agree
# 2                               1 - Strongly Disagree
# 3                                  5 - Strongly agree
# 4                                                   3
# 5                                                   4
# 6                                  5 - Strongly agree
# 7                                                   4
# 8                                  5 - Strongly agree
# 9                                  5 - Strongly agree
# 10                                                  3
#
#    I thought there was too much inconsistency in OnSET.  ...  \
# 0                               1 - Strongly Disagree    ...
# 1                                                   2    ...
# 2                               1 - Strongly Disagree    ...
# 3                                                   2    ...
# 4                                                   2    ...
# 5                               1 - Strongly Disagree    ...
# 6                               1 - Strongly Disagree    ...
# 7                                  5 - Strongly agree    ...
# 8                                                   4    ...
# 9                                                   2    ...
# 10                                                  2    ...
#
#    I needed to learn a lot of things before I could get going with OnSET.  \
# 0                                                   2
# 1                               1 - Strongly Disagree
# 2                               1 - Strongly Disagree
# 3                                                   2
# 4                                                   2
# 5                                                   2
# 6                                                   3
# 7                               1 - Strongly Disagree
# 8                               1 - Strongly Disagree
# 9                                                   2
# 10                                 5 - Strongly agree
#
#                                            Background Task 0 Time  \
# 0           CS Background (e.g. studying informatics)       08:30
# 1           CS Background (e.g. studying informatics)       01:40
# 2           CS Background (e.g. studying informatics)       03:50
# 3           CS Background (e.g. studying informatics)       04:00
# 4                            Non-technical background       03:00
# 5           CS Background (e.g. studying informatics)       03:00
# 6           CS Background (e.g. studying informatics)       05:00
# 7   Technical background (e.g. studying at a unive...       02:00
# 8           CS Background (e.g. studying informatics)       05:30
# 9           CS Background (e.g. studying informatics)       03:00
# 10          CS Background (e.g. studying informatics)       02:00
#
#                                  Task 0 Success Task 1 Time  \
# 0                  Correct Links; Correct Nodes       03:40
# 1   Fully Correct; Correct Nodes; Correct Links       00:40
# 2   Fully Correct; Correct Nodes; Correct Links       01:00
# 3   Fully Correct; Correct Nodes; Correct Links       00:30
# 4   Fully Correct; Correct Nodes; Correct Links       00:40
# 5   Fully Correct; Correct Nodes; Correct Links       01:30
# 6   Fully Correct; Correct Nodes; Correct Links       01:30
# 7                                 Correct Nodes       02:00
# 8   Fully Correct; Correct Nodes; Correct Links       00:50
# 9                  Correct Links; Correct Nodes       00:30
# 10  Fully Correct; Correct Nodes; Correct Links       00:30
#
#                                  Task 1 Success Task 2 Time  \
# 0                  Correct Links; Correct Nodes       02:40
# 1   Fully Correct; Correct Nodes; Correct Links       04:30
# 2   Fully Correct; Correct Nodes; Correct Links       02:30
# 3   Fully Correct; Correct Nodes; Correct Links       09:00
# 4   Fully Correct; Correct Nodes; Correct Links       05:00
# 5   Fully Correct; Correct Nodes; Correct Links       03:30
# 6   Fully Correct; Correct Nodes; Correct Links       10:00
# 7   Fully Correct; Correct Nodes; Correct Links       05:30
# 8   Fully Correct; Correct Nodes; Correct Links       03:00
# 9   Fully Correct; Correct Nodes; Correct Links       03:20
# 10  Fully Correct; Correct Nodes; Correct Links       04:00
#
#                                  Task 2 Success Task 3 Time  \
# 0   Fully Correct; Correct Nodes; Correct Links       00:40
# 1   Fully Correct; Correct Nodes; Correct Links       01:50
# 2   Fully Correct; Correct Nodes; Correct Links       01:30
# 3                                 Correct Nodes       01:00
# 4   Fully Correct; Correct Nodes; Correct Links       08:00
# 5   Fully Correct; Correct Nodes; Correct Links       01:50
# 6                                 Correct Nodes       02:50
# 7   Correct Nodes; Correct Links; Fully Correct       01:30
# 8                  Correct Links; Correct Nodes       01:40
# 9   Fully Correct; Correct Nodes; Correct Links       01:40
# 10  Fully Correct; Correct Nodes; Correct Links       00:30
#
#                                  Task 3 Success
# 0   Correct Nodes; Correct Links; Fully Correct
# 1   Fully Correct; Correct Nodes; Correct Links
# 2   Fully Correct; Correct Nodes; Correct Links
# 3   Fully Correct; Correct Nodes; Correct Links
# 4   Fully Correct; Correct Nodes; Correct Links
# 5   Fully Correct; Correct Nodes; Correct Links
# 6   Fully Correct; Correct Nodes; Correct Links
# 7   Fully Correct; Correct Nodes; Correct Links
# 8   Fully Correct; Correct Nodes; Correct Links
# 9   Fully Correct; Correct Nodes; Correct Links
# 10  Fully Correct; Correct Nodes; Correct Links
#
# [11 rows x 23 columns]

# %%
list(enumerate(df.columns))
# Out:
# [(0, 'User ID'),
#  (1, 'User display name'),
#  (2, 'Timestamp'),
#  (3, 'Participant ID'),
#  (4, ' I think that I would like to use OnSET frequently.'),
#  (5, ' I found OnSET unnecessarily complex.'),
#  (6, 'I thought OnSET was easy to use.'),
#  (7,
#   'I think that I would need the support of a technical person to be able to use OnSET.'),
#  (8, 'I found the various functions in OnSET were well integrated.'),
#  (9, 'I thought there was too much inconsistency in OnSET.'),
#  (10,
#   'I would imagine that most people would learn to use OnSET very quickly.'),
#  (11, 'I found OnSET very cumbersome to use.'),
#  (12, 'I felt very confident using OnSET.'),
#  (13,
#   'I needed to learn a lot of things before I could get going with OnSET.'),
#  (14, 'Background'),
#  (15, 'Task 0 Time'),
#  (16, 'Task 0 Success'),
#  (17, 'Task 1 Time'),
#  (18, 'Task 1 Success'),
#  (19, 'Task 2 Time'),
#  (20, 'Task 2 Success'),
#  (21, 'Task 3 Time'),
#  (22, 'Task 3 Success')]

# %%
likert_cols = {
    "Recommendable": 4,
    "Satisfaction": 10,
    "Confidence": 12,
}
positive_col_ids = [i * 2 + 4 for i in range(5)]
negative_col_ids = [col + 1 for col in positive_col_ids]

sus_cols = positive_col_ids + negative_col_ids

task_times_cols = [i * 2 + 15 for i in range(4)]
task_successes_cols = [col + 1 for col in task_times_cols]
df.iloc[:, sus_cols] = (
    df.iloc[:, sus_cols]
    .map(lambda x: pd.to_numeric(x[0]) if isinstance(x, str) else pd.to_numeric(x))
    .astype(int)
)
df = df.infer_objects()
df["sus"] = (
    df.iloc[:, positive_col_ids].to_numpy()
    - 1
    + 5
    - df.iloc[:, negative_col_ids].to_numpy()
).sum(axis=1) * 2.5
df
# Out:
#     User ID User display name                  Timestamp Participant ID  \
# 0       NaN    Anonymous user  2025-06-03T10:42:18+02:00           IT28
# 1       NaN    Anonymous user  2025-06-03T12:00:40+02:00           SR01
# 2       NaN    Anonymous user  2025-06-03T14:57:47+02:00           SI01
# 3       NaN    Anonymous user  2025-06-04T13:52:37+02:00           RR15
# 4       NaN    Anonymous user  2025-06-07T16:31:02+02:00           MH02
# 5       NaN    Anonymous user  2025-06-17T15:55:44+02:00           PA25
# 6       NaN    Anonymous user  2025-06-18T11:13:33+02:00           JK17
# 7       NaN    Anonymous user  2025-06-23T11:08:24+02:00           SR17
# 8       NaN    Anonymous user  2025-06-23T13:04:47+02:00           MT23
# 9       NaN    Anonymous user  2025-06-27T10:49:14+02:00           Mr15
# 10      NaN    Anonymous user  2025-07-02T11:17:07+02:00           TE02
#
#      I think that I would like to use OnSET frequently.  \
# 0                                                   3
# 1                                                   4
# 2                                                   1
# 3                                                   4
# 4                                                   3
# 5                                                   4
# 6                                                   4
# 7                                                   4
# 8                                                   4
# 9                                                   4
# 10                                                  3
#
#      I found OnSET unnecessarily complex.  I thought OnSET was easy to use.  \
# 0                                       1                                 4
# 1                                       2                                 4
# 2                                       1                                 2
# 3                                       1                                 4
# 4                                       2                                 4
# 5                                       3                                 4
# 6                                       2                                 3
# 7                                       1                                 5
# 8                                       5                                 5
# 9                                       1                                 4
# 10                                      2                                 4
#
#     I think that I would need the support of a technical person to be able to use OnSET.  \
# 0                                                   4
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                   3
# 5                                                   4
# 6                                                   4
# 7                                                   3
# 8                                                   5
# 9                                                   3
# 10                                                  2
#
#     I found the various functions in OnSET were well integrated.  \
# 0                                                   3
# 1                                                   5
# 2                                                   1
# 3                                                   5
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   4
# 8                                                   5
# 9                                                   5
# 10                                                  3
#
#     I thought there was too much inconsistency in OnSET.  ...  \
# 0                                                   1     ...
# 1                                                   2     ...
# 2                                                   1     ...
# 3                                                   2     ...
# 4                                                   2     ...
# 5                                                   1     ...
# 6                                                   1     ...
# 7                                                   5     ...
# 8                                                   4     ...
# 9                                                   2     ...
# 10                                                  2     ...
#
#                                            Background  Task 0 Time  \
# 0           CS Background (e.g. studying informatics)        08:30
# 1           CS Background (e.g. studying informatics)        01:40
# 2           CS Background (e.g. studying informatics)        03:50
# 3           CS Background (e.g. studying informatics)        04:00
# 4                            Non-technical background        03:00
# 5           CS Background (e.g. studying informatics)        03:00
# 6           CS Background (e.g. studying informatics)        05:00
# 7   Technical background (e.g. studying at a unive...        02:00
# 8           CS Background (e.g. studying informatics)        05:30
# 9           CS Background (e.g. studying informatics)        03:00
# 10          CS Background (e.g. studying informatics)        02:00
#
#                                  Task 0 Success  Task 1 Time  \
# 0                  Correct Links; Correct Nodes        03:40
# 1   Fully Correct; Correct Nodes; Correct Links        00:40
# 2   Fully Correct; Correct Nodes; Correct Links        01:00
# 3   Fully Correct; Correct Nodes; Correct Links        00:30
# 4   Fully Correct; Correct Nodes; Correct Links        00:40
# 5   Fully Correct; Correct Nodes; Correct Links        01:30
# 6   Fully Correct; Correct Nodes; Correct Links        01:30
# 7                                 Correct Nodes        02:00
# 8   Fully Correct; Correct Nodes; Correct Links        00:50
# 9                  Correct Links; Correct Nodes        00:30
# 10  Fully Correct; Correct Nodes; Correct Links        00:30
#
#                                  Task 1 Success Task 2 Time  \
# 0                  Correct Links; Correct Nodes       02:40
# 1   Fully Correct; Correct Nodes; Correct Links       04:30
# 2   Fully Correct; Correct Nodes; Correct Links       02:30
# 3   Fully Correct; Correct Nodes; Correct Links       09:00
# 4   Fully Correct; Correct Nodes; Correct Links       05:00
# 5   Fully Correct; Correct Nodes; Correct Links       03:30
# 6   Fully Correct; Correct Nodes; Correct Links       10:00
# 7   Fully Correct; Correct Nodes; Correct Links       05:30
# 8   Fully Correct; Correct Nodes; Correct Links       03:00
# 9   Fully Correct; Correct Nodes; Correct Links       03:20
# 10  Fully Correct; Correct Nodes; Correct Links       04:00
#
#                                  Task 2 Success Task 3 Time  \
# 0   Fully Correct; Correct Nodes; Correct Links       00:40
# 1   Fully Correct; Correct Nodes; Correct Links       01:50
# 2   Fully Correct; Correct Nodes; Correct Links       01:30
# 3                                 Correct Nodes       01:00
# 4   Fully Correct; Correct Nodes; Correct Links       08:00
# 5   Fully Correct; Correct Nodes; Correct Links       01:50
# 6                                 Correct Nodes       02:50
# 7   Correct Nodes; Correct Links; Fully Correct       01:30
# 8                  Correct Links; Correct Nodes       01:40
# 9   Fully Correct; Correct Nodes; Correct Links       01:40
# 10  Fully Correct; Correct Nodes; Correct Links       00:30
#
#                                  Task 3 Success   sus
# 0   Correct Nodes; Correct Links; Fully Correct  67.5
# 1   Fully Correct; Correct Nodes; Correct Links  82.5
# 2   Fully Correct; Correct Nodes; Correct Links  55.0
# 3   Fully Correct; Correct Nodes; Correct Links  90.0
# 4   Fully Correct; Correct Nodes; Correct Links  67.5
# 5   Fully Correct; Correct Nodes; Correct Links  72.5
# 6   Fully Correct; Correct Nodes; Correct Links  65.0
# 7   Fully Correct; Correct Nodes; Correct Links  77.5
# 8   Fully Correct; Correct Nodes; Correct Links  70.0
# 9   Fully Correct; Correct Nodes; Correct Links  77.5
# 10  Fully Correct; Correct Nodes; Correct Links  60.0
#
# [11 rows x 24 columns]

# %%
sus= df["sus"].mean()
sus
# Out:
# np.float64(71.36363636363636)

# %%
task_times_cols
# Out:
# [15, 17, 19, 21]

# %%
df.iloc[:, task_times_cols] = (
    df.iloc[:, task_times_cols]
    .map(lambda x: pd.to_timedelta(f"00:{x}"))
    .map(lambda x: x.total_seconds() / 60)
)
task_times_mean = df.iloc[:, task_times_cols].mean(axis=0)
task_times_totals = df.iloc[:, task_times_cols].sum(axis=1)

task_full_correct = (
    df.iloc[:, task_successes_cols]
    .map(lambda cor: 1 if "Fully Correct" in cor else 0)
    .mean(axis=0)
)
task_times_totals
# Out:
# 0          15.5
# 1      8.666667
# 2      8.833333
# 3          14.5
# 4     16.666667
# 5      9.833333
# 6     19.333333
# 7          11.0
# 8          11.0
# 9           8.5
# 10          7.0
# dtype: object

# %%
df.iloc[:, task_times_cols[1:]].to_numpy().flatten()
# Out:
# array([3.6666666666666665, 2.6666666666666665, 0.6666666666666666,
#        0.6666666666666666, 4.5, 1.8333333333333333, 1.0, 2.5, 1.5, 0.5,
#        9.0, 1.0, 0.6666666666666666, 5.0, 8.0, 1.5, 3.5,
#        1.8333333333333333, 1.5, 10.0, 2.8333333333333335, 2.0, 5.5, 1.5,
#        0.8333333333333334, 3.0, 1.6666666666666667, 0.5,
#        3.3333333333333335, 1.6666666666666667, 0.5, 4.0, 0.5],
#       dtype=object)

# %%
import scipy.stats as stats

test=stats.ttest_ind(
    df.iloc[:, task_times_cols[0]].to_numpy().flatten().astype(float),
    df.iloc[:, task_times_cols[1:]].to_numpy().flatten().astype(float),
    equal_var=False,
)
test
# Out:
# TtestResult(statistic=np.float64(1.4499115896295625), pvalue=np.float64(0.1618246015245959), df=np.float64(21.04373701826846))

# %%
task_df = pd.DataFrame(
    {
        "Task": [f"Task {i}" for i in range(task_times_mean.shape[0])],
        "Time": task_times_mean.to_list(),
        "Success Rate": task_full_correct.to_list(),
    }
)
task_df["Time (delta)"] = task_df["Time"].apply(lambda x: pd.to_timedelta(x, unit="m"))
task_df["Time (mm:ss)"] = task_df["Time (delta)"].apply(lambda x: f"{x.components.minutes:02d}:{x.components.seconds:02d}")


with open("../tables/task_results.tex", "w") as f:
    f.write(
        task_df[["Task","Success Rate", "Time (mm:ss)"]].to_latex(
            float_format="%.2f",
            caption=f"Task results for the OnSET user study on DBpedia with $n={df.shape[0]}$.",
            label="tab:task_results",
            index=False,
            formatters={},
        )
    )
task_df
# Out:
#      Task      Time  Success Rate              Time (delta) Time (mm:ss)
# 0  Task 0  3.772727      0.727273 0 days 00:03:46.363636362        03:46
# 1  Task 1  1.212121      0.909091 0 days 00:01:12.727272726        01:12
# 2  Task 2  4.818182      0.727273 0 days 00:04:49.090909092        04:49
# 3  Task 3  2.090909      1.000000 0 days 00:02:05.454545454        02:05
