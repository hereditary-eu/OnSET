# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))
sys.path.append(os.path.abspath("../backend"))
sys.path.append(os.path.abspath(""))

# %%
from backend.ontology import *
base_path = "../data"
onto_path = base_path + "/hero-ontology/hereditary_clinical.ttl"
brainteaser_graph = Graph().parse(onto_path, format="turtle")
brainteaser_graph.bind("bto", "http://www.semanticweb.org/ontologies/2020/3/bto#")
oman = OntologyManager(OntologyConfig(), brainteaser_graph)
# Out:
# -- Loading and merging datasets
# 0 datasets loaded

# %%
classes=oman.q_to_df("""
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?s
WHERE {
    # ?s rdf:type owl:Class.
}
""")[0].to_list()
classes
# Out:
# [rdflib.term.BNode('n77c7c2203b4a4474bc936853811f4bdfb1'),
#  rdflib.term.URIRef('http://ontology.eil.utoronto.ca/GCI/Environment/Pollution.owl#Air_pollution_concentration'),
#  rdflib.term.URIRef('http://purl.oclc.org/NET/ssnx/ssn#SensingDevice'),
#  rdflib.term.URIRef('http://www.w3.org/2000/10/swap/pim/contact#Person'),
#  rdflib.term.URIRef('http://www.w3.org/2006/time#Instant'),
#  rdflib.term.URIRef('http://www.wurvoc.org/vocabularies/om-1.8/Unit_of_measure'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/ALSFRS'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Activity'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Administration'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/AdverseDrugReaction'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/AnatomicalSite'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/BeforeOnset'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/C6H6_concentration'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/CO_concentration'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/CSFAnalysis'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/ClinicalEvaluation'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/ClinicalTrial'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/ClinicalTrialParticipation'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/ClinicsAndHospitals'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Comorbidity'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Condition'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Diagnosis'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/DiagnosticImaging'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/DiagnosticProcedure'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/EDSS'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/EndTherapyReason'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Event'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/EvokedPotentials'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Gene'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/GeneticTesting'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Group'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/HematologyTest'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Impairment'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/InterventionOrProcedure'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/KingsClinicalStaging'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Kinship'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/KinshipType'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/LaboratoryTestResult'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Lifestyle'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/MRI'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/MiToSFunctionalStaging'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Occupation'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/OligoclonalBands'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Onset'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/PET'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Patient'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/PharmacologicSubstance'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/PhysicalActivity'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Place'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Pregnancy'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/ProtocolEvent'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/PulmonaryFunctionTest'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Questionnaire'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Relapse'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Residence'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Smoking'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/SurgicalProcedure'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/SurgicalType'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/TherapeuticProcedure'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/TherapeuticProcedureType'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/TherapeuticTreatment'),
#  rdflib.term.URIRef('https://w3id.org/brainteaser/ontology/schema/Trauma')]

# %%
classes_enriched = [oman.enrich_subject(c, load_properties=True) for  c in classes]

# %%
classes_enriched[3]
# Out:
# Subject(subject_id='<http://www.w3.org/2000/10/swap/pim/contact#Person>', label='Person', spos={'rdf:type': ['owl:Class'], 'rdfs:comment': ['A human being. [Definition Source: NCI]'], 'rdfs:label': ['Person']}, subject_type='class', refcount=0, descendants={}, total_descendants=0, properties={'ObjectProperty': [Subject(subject_id='<https://w3id.org/brainteaser/ontology/schema/birthplace>', label='birthplace', spos={'rdf:type': ['owl:ObjectProperty'], 'rdfs:domain': ['<http://www.w3.org/2000/10/swap/pim/contact#Person>'], 'rdfs:range': ['<https://w3id.org/brainteaser/ontology/schema/Place>'], 'rdfs:comment': ['It defines the relationship between a person and his or her birthplace.'], 'rdfs:label': ['birthplace']}, subject_type='individual', refcount=0, descendants={}, total_descendants=0, properties={}), Subject(subject_id='<https://w3id.org/brainteaser/ontology/schema/enrolledIn>', label='enrolledIn', spos={'rdf:type': ['owl:ObjectProperty'], 'rdfs:domain': ['<http://www.w3.org/2000/10/swap/pim/contact#Person>'], 'rdfs:range': ['<https://w3id.org/brainteaser/ontology/schema/ClinicalTrialParticipation>'], 'rdfs:comment': ['It defines the relationship between a person and a clinical trial participation. In particular, a person can be enrolled in a clinical trial participation.'], 'rdfs:label': ['enrolledIn']}, subject_type='individual', refcount=0, descendants={}, total_descendants=0, properties={}), Subject(subject_id='<https://w3id.org/brainteaser/ontology/schema/hasDisease>', label='hasDisease', spos={'rdf:type': ['owl:ObjectProperty'], 'rdfs:domain': ['<http://www.w3.org/2000/10/swap/pim/contact#Person>'], 'rdfs:range': ['<https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding>'], 'rdfs:comment': ['It defines the relationship between a person and a disease which he or she suffers from.'], 'rdfs:label': ['hasDisease']}, subject_type='individual', refcount=0, descendants={}, total_descendants=0, properties={}), Subject(subject_id='<https://w3id.org/brainteaser/ontology/schema/residence>', label='residence', spos={'rdf:type': ['owl:ObjectProperty'], 'rdfs:domain': ['<http://www.w3.org/2000/10/swap/pim/contact#Person>'], 'rdfs:range': ['<https://w3id.org/brainteaser/ontology/schema/Residence>'], 'rdfs:comment': ['It defines the relationship between a person and his or her residence.'], 'rdfs:label': ['residence']}, subject_type='individual', refcount=0, descendants={}, total_descendants=0, properties={})], 'DatatypeProperty': [Subject(subject_id='<https://w3id.org/brainteaser/ontology/schema/birthYear>', label='birthYear', spos={'rdf:type': ['owl:DatatypeProperty', 'owl:FunctionalProperty'], 'rdfs:domain': ['<http://www.w3.org/2000/10/swap/pim/contact#Person>'], 'rdfs:range': ['xsd:gYear'], 'dcterms:conformsTo': ['https://uts.nlm.nih.gov/uts/umls/concept/C2826771'], 'rdfs:comment': ['The year in which a person was born. [Definition Source: NCI]'], 'rdfs:label': ['birthYear']}, subject_type='individual', refcount=0, descendants={}, total_descendants=0, properties={}), Subject(subject_id='<https://w3id.org/brainteaser/ontology/schema/sex>', label='sex', spos={'rdf:type': ['owl:DatatypeProperty', 'owl:FunctionalProperty'], 'rdfs:domain': ['<http://www.w3.org/2000/10/swap/pim/contact#Person>'], 'rdfs:range': ['_:n77c7c2203b4a4474bc936853811f4bdfb75'], 'dcterms:conformsTo': ['https://uts.nlm.nih.gov/uts/umls/concept/C1522384'], 'rdfs:comment': ['The assemblage of physical properties or qualities by which male is distinguished from female; the physical difference between male and female; the distinguishing peculiarity of male or female. [Definition Source: NCI]'], 'rdfs:label': ['sex']}, subject_type='individual', refcount=0, descendants={}, total_descendants=0, properties={})]})

# %%
documents = []
import regex as re


def to_readable(s: str):
    return re.sub(r"([a-z])([A-Z])", r"\1 \2", s).replace("_", " ")


for c in classes_enriched[1:]:
    if c.label.startswith("<"):
        print("ignoring", c.label)
        continue
    ne_doc= f"{c.subject_id} {c.label}\n"
    nis=oman.get_named_individuals(c.subject_id)
    for ne in nis:
        ne_doc += f"{ne.label} is a {c.label}\n"
    if len(nis)>0:
        documents.append(ne_doc)
    
    document_cls = f"{c.label}"
    if "rdfs:subClassOf" in c.spos:
        subcls = oman.enrich_subject(c.spos["rdfs:subClassOf"][0])
        if subcls.label.startswith("<"):
            continue
        document_cls += f" is subclass of  {subcls.label}\n"
    
    for pt, p in c.properties.items():
        for prop in p:
            if prop.label.startswith("<"):
                continue
            if pt=="DatatypeProperty":
                document_cls += f"{c.label} is defined by {to_readable(prop.label)} "
            else:
                document_cls += f"{c.label} {to_readable(prop.label)} "
            if "rdfs:range" in prop.spos:
                range = oman.enrich_subject(prop.spos["rdfs:range"][0])
                if range.label.startswith("<"):
                    continue
                document_cls += f" of type {range.label}"
            if "rdfs:subPropertyOf" in prop.spos:
                subprop = oman.enrich_subject(prop.spos["rdfs:subPropertyOf"][0])
                if subprop.label.startswith("<"):
                    continue
                document_cls += f" is subproperty of {subprop.label}"
            document_cls += "\n"
    documents.append(document_cls)
# Out:
# ignoring <http://ontology.eil.utoronto.ca/GCI/Environment/Pollution.owl#Air_pollution_concentration>
# ignoring <http://purl.oclc.org/NET/ssnx/ssn#SensingDevice>
# ignoring <http://www.wurvoc.org/vocabularies/om-1.8/Unit_of_measure>
# ignoring <https://w3id.org/brainteaser/ontology/schema/C6H6_concentration>

# %%
print(documents[10])
# Out:
# Before Onset is subclass of  Event
# Before Onset is defined by onset Elapsed Time  of type Neck

# %%
from bertopic import BERTopic
from bertopic.representation import MaximalMarginalRelevance
from sklearn.datasets import fetch_20newsgroups

representation_model = MaximalMarginalRelevance(diversity=0.1)
topic_model = BERTopic(embedding_model="paraphrase-MiniLM-L6-v2",verbose=True
                )
topic_model.fit(documents)
# Out:
# 2024-11-19 08:40:37,211 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 2024-11-19 08:40:38,736 - BERTopic - Embedding - Completed ✓
# 2024-11-19 08:40:38,737 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-11-19 08:40:38,843 - BERTopic - Dimensionality - Completed ✓
# 2024-11-19 08:40:38,843 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-11-19 08:40:38,846 - BERTopic - Cluster - Completed ✓
# 2024-11-19 08:40:38,847 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-11-19 08:40:38,853 - BERTopic - Representation - Completed ✓

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                         Name  \
# 0     -1     29  -1_pharmacologicsubstance_is_and_occupation
# 1      0     28                0_disorder_disease_or_finding
# 2      1     12        1_procedure_surgical_type_therapeutic
#
#                                       Representation  \
# 0  [pharmacologicsubstance, is, and, occupation, ...
# 1  [disorder, disease, or, finding, is, of, by, d...
# 2  [procedure, surgical, type, therapeutic, is, o...
#
#                                  Representative_Docs
# 0  [<https://w3id.org/brainteaser/ontology/schema...
# 1  [Patient is subclass of  Person\nPatient has E...
# 2  [Surgical Procedure is subclass of  Interventi...

# %%
hierarchical_topics = topic_model.hierarchical_topics(documents)
hierarchical_topics
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 365.61it/s]
#   Parent_ID                   Parent_Name  Topics Child_Left_ID  \
# 0         2  type_of_procedure_by_defined  [0, 1]             0
#
#               Child_Left_Name Child_Right_ID  \
# 0  of_by_type_defined_relapse              1
#
#                         Child_Right_Name  Distance
# 0  procedure_surgical_type_anatomic_site   0.76809

# %%
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
